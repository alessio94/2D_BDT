// %% [markdown]
// <img src="tmva_logo.gif" height="20%" width="20%">
//
// # TMVA Classification Example

// %% [markdown]
// ## Declare Factory
//
// Create the Factory class. Later you can choose the methods
// whose performance you'd like to investigate.
//
// The factory is the major TMVA object you have to interact with. Here is the list of parameters you need to pass
//
//  - The first argument is the base of the name of all the output
// weightfiles in the directory weight/ that will be created with the
// method parameters
//
//  - The second argument is the output file for the training results
//
//  - The third argument is a string option defining some general configuration for the TMVA session. For example all TMVA output can be suppressed by removing the "!" (not) in front of the "Silent" argument in the option string

// %%
TMVA::Tools::Instance();


auto outputFile = TFile::Open("Higgs_ClassificationOutputVBFbkg.root", "RECREATE");

TMVA::Factory factory("TMVA_Higgs_Classification", outputFile,
                      "!V:ROC:!Silent:Color:!DrawProgressBar:AnalysisType=Classification" );

// %% [markdown]
// ## Setup Dataset(s)
//
// Define input data file and signal and background trees

// %%
TString inputFileName1 = "vbf_train.root";
TString inputFileName2 = "vbf_test.root";
TString inputFileName3 = "bkg_train.root";
TString inputFileName4 = "bkg_test.root";

//TString inputFileName = "tmva_class_example.root";

auto inputFile1 = TFile::Open( inputFileName1 );
auto inputFile2 = TFile::Open( inputFileName2 );
auto inputFile3 = TFile::Open( inputFileName3 );
auto inputFile4 = TFile::Open( inputFileName4 );


// --- Register the training and test trees

//TTree *signalTree     = (TTree*)inputFile1->Get("TF");
//TTree *backgroundTree = (TTree*)inputFile2->Get("TF");

TTree *signalTreeTrain     = (TTree*)inputFile1->Get("test");
TTree *signalTreeTest     = (TTree*)inputFile2->Get("test");
TTree *backgroundTreeTrain = (TTree*)inputFile3->Get("test");
TTree *backgroundTreeTest = (TTree*)inputFile4->Get("test");


signalTreeTrain->Print();
signalTreeTest->Print();
backgroundTreeTrain->Print();
backgroundTreeTest->Print();

 TH1F *hist1=new TH1F("hist_bkg","",1,-100000000000000000,10000000000000);
 backgroundTreeTest->Draw("weight>>hist_bkg");
 double weight_bkg_total = hist1->GetMean()*hist1->GetEntries();

  string weight_bkg = "weight/"+ std::to_string(weight_bkg_total);

  cout<<" w bkg:   "<<weight_bkg <<endl;

 TH1F *hist2=new TH1F("hist_sig","",1,-100000000000000000,10000000000000);
 signalTreeTest->Draw("weight>>hist_sig");
 double weight_sig_total = hist2->GetMean()*hist2->GetEntries();

  string weight_sig = "weight/"+ std::to_string(weight_sig_total);

  cout<<" w sig:   "<<weight_sig <<endl;
// Out:
// ******************************************************************************
// *Tree    :test      : bbll_ee                                                *
// *Entries :     8990 : Total =         3197558 bytes  File  Size =    2415946 *
// *        :          : Tree compression factor =   1.32                       *
// ******************************************************************************
// *Br    0 :BDTvb     : BDTvb/D                                                *
// *Entries :     8990 : Total  Size=      72623 bytes  File Size  =      69290 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    1 :BDTvg     : BDTvg/D                                                *
// *Entries :     8990 : Total  Size=      72623 bytes  File Size  =      69276 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    2 :BDTvbold  : BDTvbold/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      69303 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    3 :BDTvgold  : BDTvgold/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      69296 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    4 :BDT1D     : BDT1D/D                                                *
// *Entries :     8990 : Total  Size=      72623 bytes  File Size  =      69291 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    5 :runNum    : runNum/I                                               *
// *Entries :     8990 : Total  Size=      36591 bytes  File Size  =      16616 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   2.17     *
// *............................................................................*
// *Br    6 :Mtot      : Mtot/D                                                 *
// *Entries :     8990 : Total  Size=      72616 bytes  File Size  =      68258 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br    7 :MTHiggs   : MTHiggs/D                                              *
// *Entries :     8990 : Total  Size=      72637 bytes  File Size  =      69003 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br    8 :energy    : energy/D                                               *
// *Entries :     8990 : Total  Size=      72630 bytes  File Size  =        734 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=  98.27     *
// *............................................................................*
// *Br    9 :DiBJetMass : DiBJetMass/D                                          *
// *Entries :     8990 : Total  Size=      72658 bytes  File Size  =      68302 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   10 :DiBJetPt  : DiBJetPt/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      69264 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   11 :DiBJetDeltaR : DiBJetDeltaR/D                                      *
// *Entries :     8990 : Total  Size=      72672 bytes  File Size  =      68974 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   12 :DiBJetDeltaPhi : DiBJetDeltaPhi/D                                  *
// *Entries :     8990 : Total  Size=      72686 bytes  File Size  =      49434 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.46     *
// *............................................................................*
// *Br   13 :MjjMax    : MjjMax/D                                               *
// *Entries :     8990 : Total  Size=      72630 bytes  File Size  =      68275 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   14 :deltaetajj : deltaetajj/D                                          *
// *Entries :     8990 : Total  Size=      72658 bytes  File Size  =      41312 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.75     *
// *............................................................................*
// *Br   15 :pTjjMax   : pTjjMax/D                                              *
// *Entries :     8990 : Total  Size=      72637 bytes  File Size  =      69205 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   16 :deltaphijjmax : deltaphijjmax/D                                    *
// *Entries :     8990 : Total  Size=      72679 bytes  File Size  =      47379 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.52     *
// *............................................................................*
// *Br   17 :DiLeptonMass : DiLeptonMass/D                                      *
// *Entries :     8990 : Total  Size=      72672 bytes  File Size  =      68281 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   18 :DiLeptonPt : DiLeptonPt/D                                          *
// *Entries :     8990 : Total  Size=      72658 bytes  File Size  =      68908 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   19 :DiLeptonDeltaR : DiLeptonDeltaR/D                                  *
// *Entries :     8990 : Total  Size=      72686 bytes  File Size  =      69010 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   20 :DiLeptonDeltaPhi : DiLeptonDeltaPhi/D                              *
// *Entries :     8990 : Total  Size=      72700 bytes  File Size  =      48792 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.48     *
// *............................................................................*
// *Br   21 :Lepton0Pt : Lepton0Pt/D                                            *
// *Entries :     8990 : Total  Size=      72651 bytes  File Size  =      41451 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.74     *
// *............................................................................*
// *Br   22 :Lepton1Pt : Lepton1Pt/D                                            *
// *Entries :     8990 : Total  Size=      72651 bytes  File Size  =      41049 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.76     *
// *............................................................................*
// *Br   23 :Lepton0Eta : Lepton0Eta/D                                          *
// *Entries :     8990 : Total  Size=      72658 bytes  File Size  =      44015 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   24 :Lepton1Eta : Lepton1Eta/D                                          *
// *Entries :     8990 : Total  Size=      72658 bytes  File Size  =      44103 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   25 :Lepton0Phi : Lepton0Phi/D                                          *
// *Entries :     8990 : Total  Size=      72658 bytes  File Size  =      44551 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.62     *
// *............................................................................*
// *Br   26 :Lepton1Phi : Lepton1Phi/D                                          *
// *Entries :     8990 : Total  Size=      72658 bytes  File Size  =      44520 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.62     *
// *............................................................................*
// *Br   27 :BJet0Pt   : BJet0Pt/D                                              *
// *Entries :     8990 : Total  Size=      72637 bytes  File Size  =      45404 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.59     *
// *............................................................................*
// *Br   28 :BJet1Pt   : BJet1Pt/D                                              *
// *Entries :     8990 : Total  Size=      72637 bytes  File Size  =      44002 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   29 :BJet0Eta  : BJet0Eta/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      50826 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.42     *
// *............................................................................*
// *Br   30 :BJet1Eta  : BJet1Eta/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      50819 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.42     *
// *............................................................................*
// *Br   31 :BJet0Phi  : BJet0Phi/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      45780 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   32 :BJet1Phi  : BJet1Phi/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      45895 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.57     *
// *............................................................................*
// *Br   33 :NOtherJets : NOtherJets/D                                          *
// *Entries :     8990 : Total  Size=      72658 bytes  File Size  =       8351 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   8.64     *
// *............................................................................*
// *Br   34 :NForwardJets : NForwardJets/D                                      *
// *Entries :     8990 : Total  Size=      72672 bytes  File Size  =       9088 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   7.94     *
// *............................................................................*
// *Br   35 :minDRlj1  : minDRlj1/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      68865 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   36 :minDRlj2  : minDRlj2/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      68962 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   37 :sumC      : sumC/D                                                 *
// *Entries :     8990 : Total  Size=      72616 bytes  File Size  =      69314 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   38 :Mjl       : Mjl/D                                                  *
// *Entries :     8990 : Total  Size=      72609 bytes  File Size  =      68278 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   39 :pTtot     : pTtot/D                                                *
// *Entries :     8990 : Total  Size=      72623 bytes  File Size  =      69009 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   40 :minDbl    : minDbl/D                                               *
// *Entries :     8990 : Total  Size=      72630 bytes  File Size  =      68748 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   41 :KLF_mtop  : KLF_mtop/D                                             *
// *Entries :     8990 : Total  Size=      72644 bytes  File Size  =      39865 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.81     *
// *............................................................................*
// *Br   42 :NN        : NN/D                                                   *
// *Entries :     8990 : Total  Size=      72602 bytes  File Size  =      68519 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   43 :eventNumber : eventNumber/I                                        *
// *Entries :     8990 : Total  Size=      36621 bytes  File Size  =      24143 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.50     *
// *............................................................................*
// *Br   44 :weight    : weight/D                                               *
// *Entries :     8990 : Total  Size=      72630 bytes  File Size  =      68243 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// ******************************************************************************
// *Tree    :test      : bbll_ee                                                *
// *Entries :    27314 : Total =         9660504 bytes  File  Size =    7318584 *
// *        :          : Tree compression factor =   1.32                       *
// ******************************************************************************
// *Br    0 :BDTvb     : BDTvb/D                                                *
// *Entries :    27314 : Total  Size=     219495 bytes  File Size  =     210292 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    1 :BDTvg     : BDTvg/D                                                *
// *Entries :    27314 : Total  Size=     219495 bytes  File Size  =     210210 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    2 :BDTvbold  : BDTvbold/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     210318 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    3 :BDTvgold  : BDTvgold/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     210209 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    4 :BDT1D     : BDT1D/D                                                *
// *Entries :    27314 : Total  Size=     219495 bytes  File Size  =     210263 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    5 :runNum    : runNum/I                                               *
// *Entries :    27314 : Total  Size=     110029 bytes  File Size  =      48462 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   2.26     *
// *............................................................................*
// *Br    6 :Mtot      : Mtot/D                                                 *
// *Entries :    27314 : Total  Size=     219484 bytes  File Size  =     207184 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br    7 :MTHiggs   : MTHiggs/D                                              *
// *Entries :    27314 : Total  Size=     219517 bytes  File Size  =     209468 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br    8 :energy    : energy/D                                               *
// *Entries :    27314 : Total  Size=     219506 bytes  File Size  =       1982 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression= 110.50     *
// *............................................................................*
// *Br    9 :DiBJetMass : DiBJetMass/D                                          *
// *Entries :    27314 : Total  Size=     219550 bytes  File Size  =     207181 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   10 :DiBJetPt  : DiBJetPt/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     210175 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   11 :DiBJetDeltaR : DiBJetDeltaR/D                                      *
// *Entries :    27314 : Total  Size=     219572 bytes  File Size  =     209342 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   12 :DiBJetDeltaPhi : DiBJetDeltaPhi/D                                  *
// *Entries :    27314 : Total  Size=     219594 bytes  File Size  =     149802 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.46     *
// *............................................................................*
// *Br   13 :MjjMax    : MjjMax/D                                               *
// *Entries :    27314 : Total  Size=     219506 bytes  File Size  =     207306 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   14 :deltaetajj : deltaetajj/D                                          *
// *Entries :    27314 : Total  Size=     219550 bytes  File Size  =     125291 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.75     *
// *............................................................................*
// *Br   15 :pTjjMax   : pTjjMax/D                                              *
// *Entries :    27314 : Total  Size=     219517 bytes  File Size  =     210037 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   16 :deltaphijjmax : deltaphijjmax/D                                    *
// *Entries :    27314 : Total  Size=     219583 bytes  File Size  =     143663 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.52     *
// *............................................................................*
// *Br   17 :DiLeptonMass : DiLeptonMass/D                                      *
// *Entries :    27314 : Total  Size=     219572 bytes  File Size  =     207290 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   18 :DiLeptonPt : DiLeptonPt/D                                          *
// *Entries :    27314 : Total  Size=     219550 bytes  File Size  =     209254 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   19 :DiLeptonDeltaR : DiLeptonDeltaR/D                                  *
// *Entries :    27314 : Total  Size=     219594 bytes  File Size  =     209378 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   20 :DiLeptonDeltaPhi : DiLeptonDeltaPhi/D                              *
// *Entries :    27314 : Total  Size=     219616 bytes  File Size  =     147566 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.48     *
// *............................................................................*
// *Br   21 :Lepton0Pt : Lepton0Pt/D                                            *
// *Entries :    27314 : Total  Size=     219539 bytes  File Size  =     125705 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.74     *
// *............................................................................*
// *Br   22 :Lepton1Pt : Lepton1Pt/D                                            *
// *Entries :    27314 : Total  Size=     219539 bytes  File Size  =     124269 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.76     *
// *............................................................................*
// *Br   23 :Lepton0Eta : Lepton0Eta/D                                          *
// *Entries :    27314 : Total  Size=     219550 bytes  File Size  =     133625 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   24 :Lepton1Eta : Lepton1Eta/D                                          *
// *Entries :    27314 : Total  Size=     219550 bytes  File Size  =     133912 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   25 :Lepton0Phi : Lepton0Phi/D                                          *
// *Entries :    27314 : Total  Size=     219550 bytes  File Size  =     134823 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.62     *
// *............................................................................*
// *Br   26 :Lepton1Phi : Lepton1Phi/D                                          *
// *Entries :    27314 : Total  Size=     219550 bytes  File Size  =     134902 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.62     *
// *............................................................................*
// *Br   27 :BJet0Pt   : BJet0Pt/D                                              *
// *Entries :    27314 : Total  Size=     219517 bytes  File Size  =     137615 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.59     *
// *............................................................................*
// *Br   28 :BJet1Pt   : BJet1Pt/D                                              *
// *Entries :    27314 : Total  Size=     219517 bytes  File Size  =     133393 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   29 :BJet0Eta  : BJet0Eta/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     153963 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.42     *
// *............................................................................*
// *Br   30 :BJet1Eta  : BJet1Eta/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     154251 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.42     *
// *............................................................................*
// *Br   31 :BJet0Phi  : BJet0Phi/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     139093 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.57     *
// *............................................................................*
// *Br   32 :BJet1Phi  : BJet1Phi/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     138984 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   33 :NOtherJets : NOtherJets/D                                          *
// *Entries :    27314 : Total  Size=     219550 bytes  File Size  =      25135 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   8.71     *
// *............................................................................*
// *Br   34 :NForwardJets : NForwardJets/D                                      *
// *Entries :    27314 : Total  Size=     219572 bytes  File Size  =      27495 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   7.97     *
// *............................................................................*
// *Br   35 :minDRlj1  : minDRlj1/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     208940 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   36 :minDRlj2  : minDRlj2/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     209141 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   37 :sumC      : sumC/D                                                 *
// *Entries :    27314 : Total  Size=     219484 bytes  File Size  =     210411 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   38 :Mjl       : Mjl/D                                                  *
// *Entries :    27314 : Total  Size=     219473 bytes  File Size  =     207230 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   39 :pTtot     : pTtot/D                                                *
// *Entries :    27314 : Total  Size=     219495 bytes  File Size  =     209454 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   40 :minDbl    : minDbl/D                                               *
// *Entries :    27314 : Total  Size=     219506 bytes  File Size  =     208752 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   41 :KLF_mtop  : KLF_mtop/D                                             *
// *Entries :    27314 : Total  Size=     219528 bytes  File Size  =     120751 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.81     *
// *............................................................................*
// *Br   42 :NN        : NN/D                                                   *
// *Entries :    27314 : Total  Size=     219462 bytes  File Size  =     208005 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   43 :eventNumber : eventNumber/I                                        *
// *Entries :    27314 : Total  Size=     110069 bytes  File Size  =      72164 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.52     *
// *............................................................................*
// *Br   44 :weight    : weight/D                                               *
// *Entries :    27314 : Total  Size=     219506 bytes  File Size  =     206638 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// ******************************************************************************
// *Tree    :test      : bbll_ee                                                *
// *Entries :   467506 : Total =       164611386 bytes  File  Size =  125023069 *
// *        :          : Tree compression factor =   1.32                       *
// ******************************************************************************
// *Br    0 :BDTvb     : BDTvb/D                                                *
// *Entries :   467506 : Total  Size=    3741101 bytes  File Size  =    3545918 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br    1 :BDTvg     : BDTvg/D                                                *
// *Entries :   467506 : Total  Size=    3741101 bytes  File Size  =    3583346 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    2 :BDTvbold  : BDTvbold/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    3544743 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br    3 :BDTvgold  : BDTvgold/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    3580463 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    4 :BDT1D     : BDT1D/D                                                *
// *Entries :   467506 : Total  Size=    3741101 bytes  File Size  =    3544865 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br    5 :runNum    : runNum/I                                               *
// *Entries :   467506 : Total  Size=    1870868 bytes  File Size  =     764433 *
// *Baskets :        5 : Basket Size=     842240 bytes  Compression=   2.45     *
// *............................................................................*
// *Br    6 :Mtot      : Mtot/D                                                 *
// *Entries :   467506 : Total  Size=    3741089 bytes  File Size  =    3545318 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br    7 :MTHiggs   : MTHiggs/D                                              *
// *Entries :   467506 : Total  Size=    3741125 bytes  File Size  =    3567934 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br    8 :energy    : energy/D                                               *
// *Entries :   467506 : Total  Size=    3741113 bytes  File Size  =      20867 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression= 179.26     *
// *............................................................................*
// *Br    9 :DiBJetMass : DiBJetMass/D                                          *
// *Entries :   467506 : Total  Size=    3741161 bytes  File Size  =    3584614 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   10 :DiBJetPt  : DiBJetPt/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    3577514 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   11 :DiBJetDeltaR : DiBJetDeltaR/D                                      *
// *Entries :   467506 : Total  Size=    3741185 bytes  File Size  =    3569194 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   12 :DiBJetDeltaPhi : DiBJetDeltaPhi/D                                  *
// *Entries :   467506 : Total  Size=    3741209 bytes  File Size  =    2558496 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.46     *
// *............................................................................*
// *Br   13 :MjjMax    : MjjMax/D                                               *
// *Entries :   467506 : Total  Size=    3741113 bytes  File Size  =    3540750 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   14 :deltaetajj : deltaetajj/D                                          *
// *Entries :   467506 : Total  Size=    3741161 bytes  File Size  =    2137813 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.75     *
// *............................................................................*
// *Br   15 :pTjjMax   : pTjjMax/D                                              *
// *Entries :   467506 : Total  Size=    3741125 bytes  File Size  =    3586061 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   16 :deltaphijjmax : deltaphijjmax/D                                    *
// *Entries :   467506 : Total  Size=    3741197 bytes  File Size  =    2449381 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.53     *
// *............................................................................*
// *Br   17 :DiLeptonMass : DiLeptonMass/D                                      *
// *Entries :   467506 : Total  Size=    3741185 bytes  File Size  =    3540808 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   18 :DiLeptonPt : DiLeptonPt/D                                          *
// *Entries :   467506 : Total  Size=    3741161 bytes  File Size  =    3565224 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   19 :DiLeptonDeltaR : DiLeptonDeltaR/D                                  *
// *Entries :   467506 : Total  Size=    3741209 bytes  File Size  =    3572830 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   20 :DiLeptonDeltaPhi : DiLeptonDeltaPhi/D                              *
// *Entries :   467506 : Total  Size=    3741233 bytes  File Size  =    2535562 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.48     *
// *............................................................................*
// *Br   21 :Lepton0Pt : Lepton0Pt/D                                            *
// *Entries :   467506 : Total  Size=    3741149 bytes  File Size  =    2121117 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.76     *
// *............................................................................*
// *Br   22 :Lepton1Pt : Lepton1Pt/D                                            *
// *Entries :   467506 : Total  Size=    3741149 bytes  File Size  =    2101671 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.78     *
// *............................................................................*
// *Br   23 :Lepton0Eta : Lepton0Eta/D                                          *
// *Entries :   467506 : Total  Size=    3741161 bytes  File Size  =    2268958 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.65     *
// *............................................................................*
// *Br   24 :Lepton1Eta : Lepton1Eta/D                                          *
// *Entries :   467506 : Total  Size=    3741161 bytes  File Size  =    2273131 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.65     *
// *............................................................................*
// *Br   25 :Lepton0Phi : Lepton0Phi/D                                          *
// *Entries :   467506 : Total  Size=    3741161 bytes  File Size  =    2294675 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.63     *
// *............................................................................*
// *Br   26 :Lepton1Phi : Lepton1Phi/D                                          *
// *Entries :   467506 : Total  Size=    3741161 bytes  File Size  =    2294582 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.63     *
// *............................................................................*
// *Br   27 :BJet0Pt   : BJet0Pt/D                                              *
// *Entries :   467506 : Total  Size=    3741125 bytes  File Size  =    2334084 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.60     *
// *............................................................................*
// *Br   28 :BJet1Pt   : BJet1Pt/D                                              *
// *Entries :   467506 : Total  Size=    3741125 bytes  File Size  =    2275806 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   29 :BJet0Eta  : BJet0Eta/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    2615409 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.43     *
// *............................................................................*
// *Br   30 :BJet1Eta  : BJet1Eta/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    2620019 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.43     *
// *............................................................................*
// *Br   31 :BJet0Phi  : BJet0Phi/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    2364422 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   32 :BJet1Phi  : BJet1Phi/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    2364978 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   33 :NOtherJets : NOtherJets/D                                          *
// *Entries :   467506 : Total  Size=    3741161 bytes  File Size  =     472835 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   7.91     *
// *............................................................................*
// *Br   34 :NForwardJets : NForwardJets/D                                      *
// *Entries :   467506 : Total  Size=    3741185 bytes  File Size  =     481519 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   7.77     *
// *............................................................................*
// *Br   35 :minDRlj1  : minDRlj1/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    3572327 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   36 :minDRlj2  : minDRlj2/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    3571693 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   37 :sumC      : sumC/D                                                 *
// *Entries :   467506 : Total  Size=    3741089 bytes  File Size  =    3579900 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   38 :Mjl       : Mjl/D                                                  *
// *Entries :   467506 : Total  Size=    3741077 bytes  File Size  =    3542716 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   39 :pTtot     : pTtot/D                                                *
// *Entries :   467506 : Total  Size=    3741101 bytes  File Size  =    3577310 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   40 :minDbl    : minDbl/D                                               *
// *Entries :   467506 : Total  Size=    3741113 bytes  File Size  =    3572013 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   41 :KLF_mtop  : KLF_mtop/D                                             *
// *Entries :   467506 : Total  Size=    3741137 bytes  File Size  =    2039666 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.83     *
// *............................................................................*
// *Br   42 :NN        : NN/D                                                   *
// *Entries :   467506 : Total  Size=    3741065 bytes  File Size  =    3563017 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   43 :eventNumber : eventNumber/I                                        *
// *Entries :   467506 : Total  Size=    1870913 bytes  File Size  =    1661258 *
// *Baskets :        5 : Basket Size=     842240 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   44 :weight    : weight/D                                               *
// *Entries :   467506 : Total  Size=    3741113 bytes  File Size  =    3537832 *
// *Baskets :        8 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// ******************************************************************************
// *Tree    :test      : bbll_ee                                                *
// *Entries :  1400556 : Total =       493109638 bytes  File  Size =  374335227 *
// *        :          : Tree compression factor =   1.32                       *
// ******************************************************************************
// *Br    0 :BDTvb     : BDTvb/D                                                *
// *Entries :  1400556 : Total  Size=   11206921 bytes  File Size  =   10622273 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br    1 :BDTvg     : BDTvg/D                                                *
// *Entries :  1400556 : Total  Size=   11206921 bytes  File Size  =   10734890 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    2 :BDTvbold  : BDTvbold/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =   10619002 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br    3 :BDTvgold  : BDTvgold/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =   10725373 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    4 :BDT1D     : BDT1D/D                                                *
// *Entries :  1400556 : Total  Size=   11206921 bytes  File Size  =   10619287 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br    5 :runNum    : runNum/I                                               *
// *Entries :  1400556 : Total  Size=    5603716 bytes  File Size  =    2250043 *
// *Baskets :       13 : Basket Size=     842240 bytes  Compression=   2.49     *
// *............................................................................*
// *Br    6 :Mtot      : Mtot/D                                                 *
// *Entries :  1400556 : Total  Size=   11206893 bytes  File Size  =   10620950 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br    7 :MTHiggs   : MTHiggs/D                                              *
// *Entries :  1400556 : Total  Size=   11206977 bytes  File Size  =   10688612 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br    8 :energy    : energy/D                                               *
// *Entries :  1400556 : Total  Size=   11206949 bytes  File Size  =      62517 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression= 179.25     *
// *............................................................................*
// *Br    9 :DiBJetMass : DiBJetMass/D                                          *
// *Entries :  1400556 : Total  Size=   11207061 bytes  File Size  =   10738070 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   10 :DiBJetPt  : DiBJetPt/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =   10716374 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   11 :DiBJetDeltaR : DiBJetDeltaR/D                                      *
// *Entries :  1400556 : Total  Size=   11207117 bytes  File Size  =   10692591 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   12 :DiBJetDeltaPhi : DiBJetDeltaPhi/D                                  *
// *Entries :  1400556 : Total  Size=   11207173 bytes  File Size  =    7663739 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.46     *
// *............................................................................*
// *Br   13 :MjjMax    : MjjMax/D                                               *
// *Entries :  1400556 : Total  Size=   11206949 bytes  File Size  =   10607291 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   14 :deltaetajj : deltaetajj/D                                          *
// *Entries :  1400556 : Total  Size=   11207061 bytes  File Size  =    6402964 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.75     *
// *............................................................................*
// *Br   15 :pTjjMax   : pTjjMax/D                                              *
// *Entries :  1400556 : Total  Size=   11206977 bytes  File Size  =   10742433 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   16 :deltaphijjmax : deltaphijjmax/D                                    *
// *Entries :  1400556 : Total  Size=   11207145 bytes  File Size  =    7336814 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.53     *
// *............................................................................*
// *Br   17 :DiLeptonMass : DiLeptonMass/D                                      *
// *Entries :  1400556 : Total  Size=   11207117 bytes  File Size  =   10606483 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   18 :DiLeptonPt : DiLeptonPt/D                                          *
// *Entries :  1400556 : Total  Size=   11207061 bytes  File Size  =   10680361 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   19 :DiLeptonDeltaR : DiLeptonDeltaR/D                                  *
// *Entries :  1400556 : Total  Size=   11207173 bytes  File Size  =   10702862 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   20 :DiLeptonDeltaPhi : DiLeptonDeltaPhi/D                              *
// *Entries :  1400556 : Total  Size=   11207229 bytes  File Size  =    7596015 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.48     *
// *............................................................................*
// *Br   21 :Lepton0Pt : Lepton0Pt/D                                            *
// *Entries :  1400556 : Total  Size=   11207033 bytes  File Size  =    6353289 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.76     *
// *............................................................................*
// *Br   22 :Lepton1Pt : Lepton1Pt/D                                            *
// *Entries :  1400556 : Total  Size=   11207033 bytes  File Size  =    6295974 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.78     *
// *............................................................................*
// *Br   23 :Lepton0Eta : Lepton0Eta/D                                          *
// *Entries :  1400556 : Total  Size=   11207061 bytes  File Size  =    6796434 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.65     *
// *............................................................................*
// *Br   24 :Lepton1Eta : Lepton1Eta/D                                          *
// *Entries :  1400556 : Total  Size=   11207061 bytes  File Size  =    6810077 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.65     *
// *............................................................................*
// *Br   25 :Lepton0Phi : Lepton0Phi/D                                          *
// *Entries :  1400556 : Total  Size=   11207061 bytes  File Size  =    6873814 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.63     *
// *............................................................................*
// *Br   26 :Lepton1Phi : Lepton1Phi/D                                          *
// *Entries :  1400556 : Total  Size=   11207061 bytes  File Size  =    6873933 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.63     *
// *............................................................................*
// *Br   27 :BJet0Pt   : BJet0Pt/D                                              *
// *Entries :  1400556 : Total  Size=   11206977 bytes  File Size  =    6991582 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.60     *
// *............................................................................*
// *Br   28 :BJet1Pt   : BJet1Pt/D                                              *
// *Entries :  1400556 : Total  Size=   11206977 bytes  File Size  =    6816244 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   29 :BJet0Eta  : BJet0Eta/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =    7833278 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.43     *
// *............................................................................*
// *Br   30 :BJet1Eta  : BJet1Eta/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =    7850187 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.43     *
// *............................................................................*
// *Br   31 :BJet0Phi  : BJet0Phi/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =    7083358 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   32 :BJet1Phi  : BJet1Phi/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =    7083984 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   33 :NOtherJets : NOtherJets/D                                          *
// *Entries :  1400556 : Total  Size=   11207061 bytes  File Size  =    1414787 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   7.92     *
// *............................................................................*
// *Br   34 :NForwardJets : NForwardJets/D                                      *
// *Entries :  1400556 : Total  Size=   11207117 bytes  File Size  =    1441803 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   7.77     *
// *............................................................................*
// *Br   35 :minDRlj1  : minDRlj1/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =   10701488 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   36 :minDRlj2  : minDRlj2/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =   10699138 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   37 :sumC      : sumC/D                                                 *
// *Entries :  1400556 : Total  Size=   11206893 bytes  File Size  =   10724990 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.04     *
// *............................................................................*
// *Br   38 :Mjl       : Mjl/D                                                  *
// *Entries :  1400556 : Total  Size=   11206865 bytes  File Size  =   10613629 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
// *Br   39 :pTtot     : pTtot/D                                                *
// *Entries :  1400556 : Total  Size=   11206921 bytes  File Size  =   10715597 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   40 :minDbl    : minDbl/D                                               *
// *Entries :  1400556 : Total  Size=   11206949 bytes  File Size  =   10700514 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   41 :KLF_mtop  : KLF_mtop/D                                             *
// *Entries :  1400556 : Total  Size=   11207005 bytes  File Size  =    6111122 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.83     *
// *............................................................................*
// *Br   42 :NN        : NN/D                                                   *
// *Entries :  1400556 : Total  Size=   11206837 bytes  File Size  =   10674060 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   43 :eventNumber : eventNumber/I                                        *
// *Entries :  1400556 : Total  Size=    5603801 bytes  File Size  =    4842166 *
// *Baskets :       13 : Basket Size=     842240 bytes  Compression=   1.16     *
// *............................................................................*
// *Br   44 :weight    : weight/D                                               *
// *Entries :  1400556 : Total  Size=   11206949 bytes  File Size  =   10592889 *
// *Baskets :       24 : Basket Size=     908288 bytes  Compression=   1.06     *
// *............................................................................*
//  w bkg:   weight/41414.031329
//  w sig:   weight/0.220228
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %% [markdown]
// ## Declare DataLoader(s)
//
// The next step is to declare the DataLoader class that deals with input variables
//
// Define the input variables that shall be used for the MVA training
// note that you may also use variable expressions, which can be parsed by TTree::Draw( "expression" )]

// %%
TMVA::DataLoader * loader = new TMVA::DataLoader("dataset");

loader->AddVariable("DiLeptonMass");
loader->AddVariable("DiLeptonPt");
//loader->AddVariable("DiLeptonDeltaR");
loader->AddVariable("DiLeptonDeltaPhi");
loader->AddVariable("MjjMax");
loader->AddVariable("deltaetajj");
loader->AddVariable("pTjjMax");
loader->AddVariable("deltaphijjmax");

loader->AddVariable("Lepton1Pt");
loader->AddVariable("Lepton1Eta");
//loader->AddVariable("Lepton1Phi");
loader->AddVariable("BJet1Pt");
loader->AddVariable("BJet1Eta");
//loader->AddVariable("BJet1Phi");

//loader->AddVariable("Lepton0Pt");
loader->AddVariable("Lepton0Eta");
//loader->AddVariable("Lepton0Phi");
//loader->AddVariable("BJet0Pt");
loader->AddVariable("BJet0Eta", "BJet0Eta", "", 'F');
//loader->AddVariable("BJet0Phi");
loader->AddVariable("Mtot");
loader->AddVariable("MTHiggs");
loader->AddVariable("DiBJetMass");
loader->AddVariable("DiBJetPt");
loader->AddVariable("DiBJetDeltaR");
loader->AddVariable("DiBJetDeltaPhi");
loader->AddVariable("minDRlj1");
loader->AddVariable("minDRlj2");
//loader->AddVariable("sumC");
//loader->AddVariable("Mjl");
loader->AddVariable("pTtot");
loader->AddVariable("minDbl");
loader->AddVariable("KLF_mtop");


loader->AddVariable("NOtherJets");
//loader->AddVariable("NForwardJets");


loader->AddSpectator("eventNumber", "eventNumber", "" );


cout<<"ok  "<<endl;
// Out:
// ok

// %% [markdown]
// We set now the input data trees in the TMVA DataLoader class

// %%
// global event weights (see below for setting event-wise weights)
Double_t weight2 = 1.0;
//TCut cutstr = "fmod(eventNumber, 2) == 0.";
//TCut cutste = "fmod(eventNumber, 2) == 1.";

//TCut cutstr = "BJet0Eta>0";
//TCut cutste = "BJet0Eta<0";

TCut cutstr = "";
TCut cutste = "";

//TCut cutstr = "(eventNumber%2)==0";
//TCut cutste = "(eventNumber%2)==1";

loader->AddTree (signalTreeTrain,        TString("Signal"), weight2, cutstr, TMVA::Types::kTraining);
loader->AddTree (signalTreeTest,          TString("Signal"), weight2, cutste, TMVA::Types::kTesting);
loader->AddTree (backgroundTreeTrain,TString("Background"), weight2, cutstr, TMVA::Types::kTraining);
loader->AddTree (backgroundTreeTest,  TString("Background"), weight2, cutste, TMVA::Types::kTesting);

cout<<"ok  "<<endl;

// set weights for individual events
loader->SetSignalWeightExpression(weight_sig);
loader->SetBackgroundWeightExpression(weight_bkg);

//loader_prepare_flags = ["nTrain_Signal=0", "nTrain_Background=0", "NormMode=None", "!V"];
//options = ":".join(loader_prepare_flags);
//loader->PrepareTrainingAndTestTree(TCut(""), TCut(""), options) ;

//loader->PrepareTrainingAndTestTree( mycuts, mycutb, "nTrain_Signal=10210:nTrain_Background=95503:SplitMode=Alternate:NormMode=NumEvents:!V" );
// Out:
// DataSetInfo              : [dataset] : Added class "Signal"
//                          : Add Tree test of type Signal with 8990 events
//                          : Add Tree test of type Signal with 27314 events
// DataSetInfo              : [dataset] : Added class "Background"
//                          : Add Tree test of type Background with 467506 events
//                          : Add Tree test of type Background with 1400556 events
// ok

// %% [markdown]
// # Booking Methods
//
// Here we book the TMVA methods. We book a Likelihood based on KDE, a Fischer discriminant and a BDT

// %%
// Likelihood ("naive Bayes estimator")
//factory.BookMethod(loader, TMVA::Types::kLikelihood, "Likelihood",
//                           "H:!V:TransformOutput:PDFInterpol=Spline2:NSmoothSig[0]=20:NSmoothBkg[0]=20:NSmoothBkg[1]=10:NSmooth=1:NAvEvtPerBin=50" );

// Use a kernel density estimator to approximate the PDFs
//factory.BookMethod(loader, TMVA::Types::kLikelihood, "LikelihoodKDE",
//                           "!H:!V:!TransformOutput:PDFInterpol=KDE:KDEtype=Gauss:KDEiter=Adaptive:KDEFineFactor=0.3:KDEborder=None:NAvEvtPerBin=50" ); 


// Fisher discriminant (same as LD)
//factory.BookMethod(loader, TMVA::Types::kFisher, "Fisher", "H:!V:Fisher:VarTransform=None:CreateMVAPdfs:PDFInterpolMVAPdf=Spline2:NbinsMVAPdf=50:NsmoothMVAPdf=10" );


//Boosted Decision Trees
factory.BookMethod(loader,TMVA::Types::kBDT, "BDT",
                   "!V:NTrees=300:MinNodeSize=2.5%:MaxDepth=4:BoostType=AdaBoost:AdaBoostBeta=0.5:UseBaggedBoost:BaggedSampleFraction=0.5:SeparationType=GiniIndex:nCuts=20" );

//Multi-Layer Perceptron (Neural Network)
//factory.BookMethod(loader, TMVA::Types::kMLP, "MLP",
//                   "!H:!V:NeuronType=tanh:VarTransform=N:NCycles=100:HiddenLayers=N+5:TestRate=5:!UseRegulator" );
// Out:
// Factory                  : Booking method: BDT
//                          :
//                          : Building event vectors for type 0 Signal
//                          : Dataset[dataset] :  create input formulas for tree test
//                          : Building event vectors for type 1 Signal
//                          : Dataset[dataset] :  create input formulas for tree test
//                          : Building event vectors for type 0 Background
//                          : Dataset[dataset] :  create input formulas for tree test
//                          : Building event vectors for type 1 Background
//                          : Dataset[dataset] :  create input formulas for tree test
// DataSetFactory           : [dataset] : Number of events in input trees
//                          :
//                          :
//                          : Dataset[dataset] : Weight renormalisation mode: "EqualNumEvents": renormalises all event classes ...
//                          : Dataset[dataset] :  such that the effective (weighted) number of events in each class is the same
//                          : Dataset[dataset] :  (and equals the number of events (entries) given for class=0 )
//                          : Dataset[dataset] : ... i.e. such that Sum[i=1..N_j]{w_i} = N_classA, j=classA, classB, ...
//                          : Dataset[dataset] : ... (note that N_j is the sum of TRAINING events
//                          : Dataset[dataset] :  ..... Testing events are not renormalised nor included in the renormalisation factor!)
//                          : Number of training and testing events
//                          : ---------------------------------------------------------------------------
//                          : Signal     -- training events            : 8990
//                          : Signal     -- testing events             : 27314
//                          : Signal     -- training and testing events: 36304
//                          : Background -- training events            : 467506
//                          : Background -- testing events             : 1400556
//                          : Background -- training and testing events: 1868062
//                          :
// DataSetInfo              : Correlation matrix (Signal):
//                          : -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//                          :                   DiLeptonMass DiLeptonPt DiLeptonDeltaPhi  MjjMax deltaetajj pTjjMax deltaphijjmax Lepton1Pt Lepton1Eta BJet1Pt BJet1Eta Lepton0Eta BJet0Eta    Mtot MTHiggs DiBJetMass DiBJetPt DiBJetDeltaR DiBJetDeltaPhi minDRlj1 minDRlj2   pTtot  minDbl KLF_mtop NOtherJets
//                          :     DiLeptonMass:       +1.000     -0.047           -0.003  -0.003     +0.009  -0.008        -0.014    +0.055     -0.003  -0.014   +0.013     +0.005   +0.024  -0.006  +0.068     -0.004   -0.018       +0.019         -0.003   +0.001   -0.059  -0.133  -0.056   +0.026     -0.005
//                          :       DiLeptonPt:       -0.047     +1.000           +0.006  +0.054     -0.092  +0.256        +0.001    +0.685     +0.013  +0.186   +0.003     +0.007   -0.006  +0.173  +0.254     +0.035   +0.307       -0.234         +0.012   +0.066   +0.077  +0.104  +0.091   -0.072     +0.038
//                          : DiLeptonDeltaPhi:       -0.003     +0.006           +1.000  -0.009     -0.008  +0.008        +0.002    +0.016     -0.009  +0.001   +0.018     -0.006   +0.015  -0.005  +0.000     -0.005   +0.005       -0.002         -0.018   +0.002   -0.005  -0.001  -0.012   -0.002     -0.000
//                          :           MjjMax:       -0.003     +0.054           -0.009  +1.000     +0.622  +0.150        -0.020    +0.060     +0.036  +0.068   -0.006     +0.030   -0.021  +0.836  +0.091     -0.005   +0.080       -0.069         -0.012   +0.178   +0.188  +0.068  +0.063   +0.005     +0.047
//                          :       deltaetajj:       +0.009     -0.092           -0.008  +0.622     +1.000  -0.365        -0.001    -0.052     -0.002  -0.053   +0.019     +0.001   +0.005  +0.359  +0.017     +0.003   -0.097       +0.087         -0.020   +0.115   +0.132  -0.096  +0.115   +0.002     +0.282
//                          :          pTjjMax:       -0.008     +0.256           +0.008  +0.150     -0.365  +1.000        -0.009    +0.190     +0.024  +0.211   -0.020     +0.022   -0.020  +0.265  +0.133     +0.010   +0.297       -0.225         +0.009   -0.019   -0.035  +0.304  -0.179   +0.017     -0.026
//                          :    deltaphijjmax:       -0.014     +0.001           +0.002  -0.020     -0.001  -0.009        +1.000    -0.021     -0.003  -0.010   +0.013     -0.000   +0.015  -0.022  -0.002     +0.004   -0.020       +0.010         +0.006   +0.009   -0.002  -0.018  +0.007   +0.002     +0.014
//                          :        Lepton1Pt:       +0.055     +0.685           +0.016  +0.060     -0.052  +0.190        -0.021    +1.000     +0.021  +0.117   +0.006     +0.016   -0.005  +0.145  +0.216     +0.029   +0.183       -0.139         +0.002   +0.032   +0.077  +0.070  +0.073   -0.091     +0.032
//                          :       Lepton1Eta:       -0.003     +0.013           -0.009  +0.036     -0.002  +0.024        -0.003    +0.021     +1.000  +0.011   -0.192     +0.821   -0.225  +0.048  +0.000     +0.016   -0.007       +0.006         +0.003   -0.002   -0.003  -0.004  +0.015   +0.002     -0.024
//                          :          BJet1Pt:       -0.014     +0.186           +0.001  +0.068     -0.053  +0.211        -0.010    +0.117     +0.011  +1.000   -0.011     +0.017   -0.012  +0.173  +0.086     +0.277   +0.603       -0.541         -0.003   -0.030   -0.026  +0.230  +0.030   +0.201     +0.019
//                          :         BJet1Eta:       +0.013     +0.003           +0.018  -0.006     +0.019  -0.020        +0.013    +0.006     -0.192  -0.011   +1.000     -0.209   +0.690  -0.022  +0.001     +0.037   -0.010       +0.025         +0.006   +0.011   +0.002  -0.004  -0.012   -0.001     +0.006
//                          :       Lepton0Eta:       +0.005     +0.007           -0.006  +0.030     +0.001  +0.022        -0.000    +0.016     +0.821  +0.017   -0.209     +1.000   -0.242  +0.042  +0.004     +0.018   -0.005       +0.008         +0.002   -0.000   +0.004  +0.001  +0.018   -0.001     -0.016
//                          :         BJet0Eta:       +0.024     -0.006           +0.015  -0.021     +0.005  -0.020        +0.015    -0.005     -0.225  -0.012   +0.690     -0.242   +1.000  -0.041  -0.015     -0.019   -0.011       +0.013         -0.002   -0.007   -0.016  -0.020  -0.015   +0.006     +0.010
//                          :             Mtot:       -0.006     +0.173           -0.005  +0.836     +0.359  +0.265        -0.022    +0.145     +0.048  +0.173   -0.022     +0.042   -0.041  +1.000  +0.183     +0.081   +0.230       -0.156         -0.010   +0.224   +0.233  +0.151  +0.153   +0.025     -0.137
//                          :          MTHiggs:       +0.068     +0.254           +0.000  +0.091     +0.017  +0.133        -0.002    +0.216     +0.000  +0.086   +0.001     +0.004   -0.015  +0.183  +1.000     -0.015   +0.173       -0.134         +0.012   -0.064   -0.049  +0.315  +0.157   -0.097     +0.054
//                          :       DiBJetMass:       -0.004     +0.035           -0.005  -0.005     +0.003  +0.010        +0.004    +0.029     +0.016  +0.277   +0.037     +0.018   -0.019  +0.081  -0.015     +1.000   +0.171       +0.224         -0.013   +0.017   +0.011  +0.095  +0.004   +0.025     +0.018
//                          :         DiBJetPt:       -0.018     +0.307           +0.005  +0.080     -0.097  +0.297        -0.020    +0.183     -0.007  +0.603   -0.010     -0.005   -0.011  +0.230  +0.173     +0.171   +1.000       -0.757         -0.010   -0.070   -0.052  +0.390  +0.053   +0.080     +0.021
//                          :     DiBJetDeltaR:       +0.019     -0.234           -0.002  -0.069     +0.087  -0.225        +0.010    -0.139     +0.006  -0.541   +0.025     +0.008   +0.013  -0.156  -0.134     +0.224   -0.757       +1.000         +0.003   +0.079   +0.059  -0.259  -0.070   -0.132     -0.029
//                          :   DiBJetDeltaPhi:       -0.003     +0.012           -0.018  -0.012     -0.020  +0.009        +0.006    +0.002     +0.003  -0.003   +0.006     +0.002   -0.002  -0.010  +0.012     -0.013   -0.010       +0.003         +1.000   -0.006   -0.015  +0.000  -0.010   +0.007     -0.007
//                          :         minDRlj1:       +0.001     +0.066           +0.002  +0.178     +0.115  -0.019        +0.009    +0.032     -0.002  -0.030   +0.011     -0.000   -0.007  +0.224  -0.064     +0.017   -0.070       +0.079         -0.006   +1.000   +0.640  -0.045  +0.044   +0.007     -0.436
//                          :         minDRlj2:       -0.059     +0.077           -0.005  +0.188     +0.132  -0.035        -0.002    +0.077     -0.003  -0.026   +0.002     +0.004   -0.016  +0.233  -0.049     +0.011   -0.052       +0.059         -0.015   +0.640   +1.000  -0.042  -0.061   -0.001     -0.413
//                          :            pTtot:       -0.133     +0.104           -0.001  +0.068     -0.096  +0.304        -0.018    +0.070     -0.004  +0.230   -0.004     +0.001   -0.020  +0.151  +0.315     +0.095   +0.390       -0.259         +0.000   -0.045   -0.042  +1.000  +0.006   +0.069     +0.073
//                          :           minDbl:       -0.056     +0.091           -0.012  +0.063     +0.115  -0.179        +0.007    +0.073     +0.015  +0.030   -0.012     +0.018   -0.015  +0.153  +0.157     +0.004   +0.053       -0.070         -0.010   +0.044   -0.061  +0.006  +1.000   +0.002     -0.024
//                          :         KLF_mtop:       +0.026     -0.072           -0.002  +0.005     +0.002  +0.017        +0.002    -0.091     +0.002  +0.201   -0.001     -0.001   +0.006  +0.025  -0.097     +0.025   +0.080       -0.132         +0.007   +0.007   -0.001  +0.069  +0.002   +1.000     +0.007
//                          :       NOtherJets:       -0.005     +0.038           -0.000  +0.047     +0.282  -0.026        +0.014    +0.032     -0.024  +0.019   +0.006     -0.016   +0.010  -0.137  +0.054     +0.018   +0.021       -0.029         -0.007   -0.436   -0.413  +0.073  -0.024   +0.007     +1.000
//                          : -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// DataSetInfo              : Correlation matrix (Background):
//                          : -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//                          :                   DiLeptonMass DiLeptonPt DiLeptonDeltaPhi  MjjMax deltaetajj pTjjMax deltaphijjmax Lepton1Pt Lepton1Eta BJet1Pt BJet1Eta Lepton0Eta BJet0Eta    Mtot MTHiggs DiBJetMass DiBJetPt DiBJetDeltaR DiBJetDeltaPhi minDRlj1 minDRlj2   pTtot  minDbl KLF_mtop NOtherJets
//                          :     DiLeptonMass:       +1.000     +0.001           -0.005  +0.004     +0.001  +0.010        +0.003    +0.255     +0.002  +0.024   +0.001     -0.002   -0.004  +0.045  +0.306     +0.054   +0.011       +0.039         -0.002   -0.007   -0.037  +0.004  -0.012   -0.006     +0.001
//                          :       DiLeptonPt:       +0.001     +1.000           +0.007  +0.029     -0.074  +0.212        -0.003    +0.428     -0.001  -0.025   +0.000     -0.002   +0.002  +0.111  +0.228     -0.034   +0.084       -0.065         -0.002   +0.066   +0.067  +0.022  -0.019   -0.118     +0.029
//                          : DiLeptonDeltaPhi:       -0.005     +0.007           +1.000  -0.002     -0.006  +0.001        +0.002    +0.000     -0.005  +0.004   +0.001     -0.002   -0.000  +0.004  -0.001     +0.005   +0.004       +0.003         -0.004   -0.003   +0.003  +0.005  -0.001   +0.005     -0.002
//                          :           MjjMax:       +0.004     +0.029           -0.002  +1.000     +0.571  +0.125        +0.004    +0.015     +0.001  +0.024   -0.003     +0.003   +0.004  +0.515  +0.018     +0.014   +0.054       -0.015         +0.000   +0.083   +0.090  +0.080  -0.020   +0.005     +0.153
//                          :       deltaetajj:       +0.001     -0.074           -0.006  +0.571     +1.000  -0.431        +0.009    -0.038     +0.002  -0.028   -0.005     +0.005   +0.001  -0.040  -0.018     -0.017   -0.126       +0.045         -0.000   +0.039   +0.049  -0.124  +0.055   +0.003     +0.353
//                          :          pTjjMax:       +0.010     +0.212           +0.001  +0.125     -0.431  +1.000        -0.000    +0.116     +0.004  +0.109   +0.001     +0.001   +0.004  +0.351  +0.093     +0.053   +0.367       -0.125         -0.001   -0.042   -0.048  +0.388  -0.141   +0.000     -0.050
//                          :    deltaphijjmax:       +0.003     -0.003           +0.002  +0.004     +0.009  -0.000        +1.000    -0.003     -0.003  +0.002   -0.001     -0.001   +0.002  -0.001  +0.004     +0.001   -0.006       +0.005         -0.002   -0.000   -0.003  -0.000  +0.001   -0.006     +0.003
//                          :        Lepton1Pt:       +0.255     +0.428           +0.000  +0.015     -0.038  +0.116        -0.003    +1.000     -0.000  -0.024   -0.001     -0.000   -0.002  +0.054  +0.102     -0.055   +0.035       -0.063         +0.001   +0.043   +0.067  -0.043  -0.074   -0.082     +0.007
//                          :       Lepton1Eta:       +0.002     -0.001           -0.005  +0.001     +0.002  +0.004        -0.003    -0.000     +1.000  -0.001   +0.336     +0.522   +0.442  -0.002  -0.003     -0.002   -0.002       -0.002         +0.001   -0.007   -0.009  +0.004  +0.003   +0.001     +0.008
//                          :          BJet1Pt:       +0.024     -0.025           +0.004  +0.024     -0.028  +0.109        +0.002    -0.024     -0.001  +1.000   -0.000     -0.002   +0.002  +0.173  +0.019     +0.670   +0.241       +0.133         +0.002   -0.005   -0.009  +0.031  -0.085   +0.154     +0.009
//                          :         BJet1Eta:       +0.001     +0.000           +0.001  -0.003     -0.005  +0.001        -0.001    -0.001     +0.336  -0.000   +1.000     +0.393   +0.242  +0.003  +0.001     +0.002   +0.003       -0.001         -0.001   -0.000   -0.001  +0.002  +0.000   -0.002     -0.001
//                          :       Lepton0Eta:       -0.002     -0.002           -0.002  +0.003     +0.005  +0.001        -0.001    -0.000     +0.522  -0.002   +0.393     +1.000   +0.490  -0.001  -0.004     -0.005   -0.002       -0.003         +0.001   -0.006   -0.009  -0.000  +0.001   +0.000     +0.008
//                          :         BJet0Eta:       -0.004     +0.002           -0.000  +0.004     +0.001  +0.004        +0.002    -0.002     +0.442  +0.002   +0.242     +0.490   +1.000  +0.003  -0.004     +0.002   +0.003       +0.000         +0.001   -0.002   -0.005  +0.001  -0.002   -0.002     +0.003
//                          :             Mtot:       +0.045     +0.111           +0.004  +0.515     -0.040  +0.351        -0.001    +0.054     -0.002  +0.173   +0.003     -0.001   +0.003  +1.000  +0.160     +0.201   +0.201       +0.035         +0.003   +0.165   +0.170  +0.198  -0.037   +0.008     -0.152
//                          :          MTHiggs:       +0.306     +0.228           -0.001  +0.018     -0.018  +0.093        +0.004    +0.102     -0.003  +0.019   +0.001     -0.004   -0.004  +0.160  +1.000     +0.031   +0.047       +0.001         -0.003   -0.075   -0.045  +0.436  -0.043   -0.101     +0.031
//                          :       DiBJetMass:       +0.054     -0.034           +0.005  +0.014     -0.017  +0.053        +0.001    -0.055     -0.002  +0.670   +0.002     -0.005   +0.002  +0.201  +0.031     +1.000   +0.161       +0.631         -0.000   -0.010   -0.008  +0.040  -0.027   +0.093     +0.012
//                          :         DiBJetPt:       +0.011     +0.084           +0.004  +0.054     -0.126  +0.367        -0.006    +0.035     -0.002  +0.241   +0.003     -0.002   +0.003  +0.201  +0.047     +0.161   +1.000       -0.440         -0.002   -0.069   -0.060  +0.184  -0.054   +0.030     +0.041
//                          :     DiBJetDeltaR:       +0.039     -0.065           +0.003  -0.015     +0.045  -0.125        +0.005    -0.063     -0.002  +0.133   -0.001     -0.003   +0.000  +0.035  +0.001     +0.631   -0.440       +1.000         -0.001   +0.030   +0.025  -0.053  -0.011   +0.014     -0.011
//                          :   DiBJetDeltaPhi:       -0.002     -0.002           -0.004  +0.000     -0.000  -0.001        -0.002    +0.001     +0.001  +0.002   -0.001     +0.001   +0.001  +0.003  -0.003     -0.000   -0.002       -0.001         +1.000   +0.002   +0.003  +0.001  -0.004   +0.002     +0.001
//                          :         minDRlj1:       -0.007     +0.066           -0.003  +0.083     +0.039  -0.042        -0.000    +0.043     -0.007  -0.005   -0.000     -0.006   -0.002  +0.165  -0.075     -0.010   -0.069       +0.030         +0.002   +1.000   +0.446  -0.081  +0.003   +0.012     -0.366
//                          :         minDRlj2:       -0.037     +0.067           +0.003  +0.090     +0.049  -0.048        -0.003    +0.067     -0.009  -0.009   -0.001     -0.009   -0.005  +0.170  -0.045     -0.008   -0.060       +0.025         +0.003   +0.446   +1.000  -0.071  -0.103   +0.012     -0.351
//                          :            pTtot:       +0.004     +0.022           +0.005  +0.080     -0.124  +0.388        -0.000    -0.043     +0.004  +0.031   +0.002     -0.000   +0.001  +0.198  +0.436     +0.040   +0.184       -0.053         +0.001   -0.081   -0.071  +1.000  -0.065   +0.014     +0.084
//                          :           minDbl:       -0.012     -0.019           -0.001  -0.020     +0.055  -0.141        +0.001    -0.074     +0.003  -0.085   +0.000     +0.001   -0.002  -0.037  -0.043     -0.027   -0.054       -0.011         -0.004   +0.003   -0.103  -0.065  +1.000   -0.038     -0.003
//                          :         KLF_mtop:       -0.006     -0.118           +0.005  +0.005     +0.003  +0.000        -0.006    -0.082     +0.001  +0.154   -0.002     +0.000   -0.002  +0.008  -0.101     +0.093   +0.030       +0.014         +0.002   +0.012   +0.012  +0.014  -0.038   +1.000     -0.013
//                          :       NOtherJets:       +0.001     +0.029           -0.002  +0.153     +0.353  -0.050        +0.003    +0.007     +0.008  +0.009   -0.001     +0.008   +0.003  -0.152  +0.031     +0.012   +0.041       -0.011         +0.001   -0.366   -0.351  +0.084  -0.003   -0.013     +1.000
//                          : -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// DataSetFactory           : [dataset] :
//                          :

// %% [markdown]
// ### Booking Deep Neural Network
//
// Here we book the new DNN of TMVA. If using master version you can use the new DL method

// %%
bool useDL = false;

// %% [markdown]
// #### 1. Define DNN layout
//
// The DNN configuration os defined using a string. Note that whitespaces between characters are not allowed.
//
// We define first the DNN layout:
//
// - **input layout** :   this defines the input data format for the DNN as  ``input depth | height | width``.
//    In case of a dense layer as first layer the input layout should be  ``1 | 1 | number of input variables`` (features)
// - **batch layout**  : this defines how are the input batch. It is related to input layout but not the same.
//    If the first layer is dense it should be ``1 | batch size ! number of variables`` (fetures)
//
//    *(note the use of the character `|` as  separator of  input parameters for DNN layout)*
//
// - **layer layout** string defining the layer architecture. The syntax is
//    - layer type (e.g. DENSE, CONV, RNN)
//    - layer parameters (e.g. number of units)
//    - activation function (e.g  TANH, RELU,...)
//
//      *the different layers are separated by the ``","`` *
//
// #### 2. Define Trainining Strategy
//
// We define here the training strategy parameters for the DNN. The parameters are separated by the ``","`` separator.
// One can then concatenate different training strategy with different parameters. The training strategy are separated by
// the ``"|"`` separator.
//
//  - Optimizer
//  - Learning rate
//  - Momentum (valid for SGD and RMSPROP)
//  - Regularization and Weight Decay
//  - Dropout
//  - Max number of epochs
//  - Convergence steps. if the test error will not decrease after that value the training will stop
//  - Batch size (This value must be the same specified in the input layout)
//  - Test Repetitions (the interval when the test error will be computed)
//
//
// #### 3. Define general DNN options
//
// We define the general DNN options concateneting in the final string the previously defined layout and training strategy.
// Note we use the ``":"`` separator to separate the different higher level options, as in the other TMVA methods.
// In addition to input layout, batch layout and training strategy we add now:
//
// - Type of Loss function (e.g. cross entropy)
// - Weight Initizalization (e.g XAVIER, XAVIERUNIFORM, NORMAL )
// - Variable Transformation
// - Type of Architecture (e.g. CPU, GPU, Standard)
//
// We can then book the DL method using the built otion string

// %%
if (useDL) {  
     // Define DNN layout
     TString inputLayoutString = "InputLayout=1|1|25"; 
     TString batchLayoutString= "BatchLayout=1|128|25";
     TString layoutString ("Layout=DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|1|LINEAR");
                                                                                                                                                                                    
      // Define Training strategies 
      // one can catenate several training strategies 
      TString training1("LearningRate=1e-3,Momentum=0.9,Repetitions=1,"
                        "ConvergenceSteps=10,BatchSize=128,TestRepetitions=1,"
                        "MaxEpochs=30,WeightDecay=1e-4,Regularization=None,"
                        "Optimizer=ADAM,DropConfig=0.0+0.0+0.0+0.");
 //     TString training2("LearningRate=1e-3,Momentum=0.9,Repetitions=1,"
 //                       "ConvergenceSteps=10,BatchSize=128,TestRepetitions=1,"
 //                       "MaxEpochs=20,WeightDecay=1e-4,Regularization=None,"
 //                       "Optimizer=SGD,DropConfig=0.0+0.0+0.0+0.");
  
      TString trainingStrategyString ("TrainingStrategy=");
      trainingStrategyString += training1; // + "|" + training2;

      // General Options.                                                                                                                                                                
      TString dnnOptions ("!H:V:ErrorStrategy=CROSSENTROPY:VarTransform=G:"
                          "WeightInitialization=XAVIER");
      dnnOptions.Append (":"); dnnOptions.Append (inputLayoutString);
      dnnOptions.Append (":"); dnnOptions.Append (batchLayoutString);
      dnnOptions.Append (":"); dnnOptions.Append (layoutString);
      dnnOptions.Append (":"); dnnOptions.Append (trainingStrategyString);

      dnnOptions += ":Architecture=CPU";
      factory.BookMethod(loader, TMVA::Types::kDL, "DL_CPU", dnnOptions);

}

// %% [markdown]
// ## Train Methods
//
// Here we train all the previously booked methods.

// %%
factory.TrainAllMethods();
// Out:
// Factory                  : Train all methods
// Factory                  : [dataset] : Create Transformation "I" with events from all classes.
//                          :
//                          : Transformation, Variable selection :
//                          : Input : variable 'DiLeptonMass' <---> Output : variable 'DiLeptonMass'
//                          : Input : variable 'DiLeptonPt' <---> Output : variable 'DiLeptonPt'
//                          : Input : variable 'DiLeptonDeltaPhi' <---> Output : variable 'DiLeptonDeltaPhi'
//                          : Input : variable 'MjjMax' <---> Output : variable 'MjjMax'
//                          : Input : variable 'deltaetajj' <---> Output : variable 'deltaetajj'
//                          : Input : variable 'pTjjMax' <---> Output : variable 'pTjjMax'
//                          : Input : variable 'deltaphijjmax' <---> Output : variable 'deltaphijjmax'
//                          : Input : variable 'Lepton1Pt' <---> Output : variable 'Lepton1Pt'
//                          : Input : variable 'Lepton1Eta' <---> Output : variable 'Lepton1Eta'
//                          : Input : variable 'BJet1Pt' <---> Output : variable 'BJet1Pt'
//                          : Input : variable 'BJet1Eta' <---> Output : variable 'BJet1Eta'
//                          : Input : variable 'Lepton0Eta' <---> Output : variable 'Lepton0Eta'
//                          : Input : variable 'BJet0Eta' <---> Output : variable 'BJet0Eta'
//                          : Input : variable 'Mtot' <---> Output : variable 'Mtot'
//                          : Input : variable 'MTHiggs' <---> Output : variable 'MTHiggs'
//                          : Input : variable 'DiBJetMass' <---> Output : variable 'DiBJetMass'
//                          : Input : variable 'DiBJetPt' <---> Output : variable 'DiBJetPt'
//                          : Input : variable 'DiBJetDeltaR' <---> Output : variable 'DiBJetDeltaR'
//                          : Input : variable 'DiBJetDeltaPhi' <---> Output : variable 'DiBJetDeltaPhi'
//                          : Input : variable 'minDRlj1' <---> Output : variable 'minDRlj1'
//                          : Input : variable 'minDRlj2' <---> Output : variable 'minDRlj2'
//                          : Input : variable 'pTtot' <---> Output : variable 'pTtot'
//                          : Input : variable 'minDbl' <---> Output : variable 'minDbl'
//                          : Input : variable 'KLF_mtop' <---> Output : variable 'KLF_mtop'
//                          : Input : variable 'NOtherJets' <---> Output : variable 'NOtherJets'
// TFHandler_Factory        :         Variable                Mean                RMS        [        Min                Max ]
//                          : ---------------------------------------------------------------------------------------------------
//                          :     DiLeptonMass:            50550.            21645.   [            15000.        1.1000e+05 ]
//                          :       DiLeptonPt:            77476.            46888.   [            77.334        1.1216e+06 ]
//                          : DiLeptonDeltaPhi:        -0.0088557            1.4701   [           -3.1416            3.1416 ]
//                          :           MjjMax:        1.3973e+06        7.2114e+05   [        6.0000e+05        7.4347e+06 ]
//                          :       deltaetajj:            6.3387            1.1189   [            4.0000            9.5141 ]
//                          :          pTjjMax:        1.1078e+05            89657.   [            93.323        1.9539e+06 ]
//                          :    deltaphijjmax:          0.022328            2.5618   [           -6.2724            6.2790 ]
//                          :        Lepton1Pt:            28115.            15564.   [            9000.0        3.8418e+05 ]
//                          :       Lepton1Eta:        -0.0028578            1.1733   [           -2.6996            2.6990 ]
//                          :          BJet1Pt:            53183.            28502.   [            20000.        9.4298e+05 ]
//                          :         BJet1Eta:        -0.0026519            1.1965   [           -2.5000            2.5000 ]
//                          :       Lepton0Eta:        -0.0019840            1.1237   [           -2.6994            2.6954 ]
//                          :         BJet0Eta:         -0.012231            1.1367   [           -2.5000            2.4998 ]
//                          :             Mtot:        1.6228e+06        8.5451e+05   [        2.2999e+05        1.0258e+07 ]
//                          :          MTHiggs:        1.4690e+05            61279.   [            16747.        1.2848e+06 ]
//                          :       DiBJetMass:        1.3172e+05            78150.   [            10225.        3.3733e+06 ]
//                          :         DiBJetPt:        1.1118e+05            75429.   [            180.56        1.4633e+06 ]
//                          :     DiBJetDeltaR:            2.0714           0.81562   [           0.38685            5.8520 ]
//                          :   DiBJetDeltaPhi:         0.0041790            1.8873   [           -3.1416            3.1416 ]
//                          :         minDRlj1:            2.1480           0.87163   [           0.38519            5.2797 ]
//                          :         minDRlj2:            2.0903           0.86357   [           0.38292            5.2365 ]
//                          :            pTtot:            85259.            58604.   [            80.899        1.0374e+06 ]
//                          :           minDbl:            2.3652           0.91899   [           0.39352            5.8871 ]
//                          :         KLF_mtop:            162.20            292.36   [           -999.00            700.00 ]
//                          :       NOtherJets:            4.1831            1.9499   [            2.0000            54.000 ]
//                          : ---------------------------------------------------------------------------------------------------
//                          :
//                          : <PlotVariables> Will not produce scatter plots ==>
//                          : |  The number of 25 input variables and 0 target values would require 300 two-dimensional
//                          : |  histograms, which would occupy the computer's memory. Note that this
//                          : |  suppression does not have any consequences for your analysis, other
//                          : |  than not disposing of these scatter plots. You can modify the maximum
//                          : |  number of input variables allowed to generate scatter plots in your
//                          : |  script via the command line:
//                          : |  "(TMVA::gConfig().GetVariablePlotting()).fMaxNumOfAllowedVariablesForScatterPlots = <some int>;"
//                          :
//                          : Some more output
//                          : Ranking input variables (method unspecific)...
// IdTransformation         : Ranking result (top variable is best ranked)
//                          : -----------------------------------------
//                          : Rank : Variable         : Separation
//                          : -----------------------------------------
//                          :    1 : DiBJetMass       : 3.233e-01
//                          :    2 : Mtot             : 2.141e-01
//                          :    3 : KLF_mtop         : 1.657e-01
//                          :    4 : NOtherJets       : 1.553e-01
//                          :    5 : DiLeptonMass     : 1.528e-01
//                          :    6 : minDRlj1         : 1.338e-01
//                          :    7 : minDbl           : 1.332e-01
//                          :    8 : minDRlj2         : 1.264e-01
//                          :    9 : MjjMax           : 9.260e-02
//                          :   10 : DiBJetDeltaR     : 7.182e-02
//                          :   11 : MTHiggs          : 5.749e-02
//                          :   12 : DiLeptonDeltaPhi : 4.282e-02
//                          :   13 : DiBJetPt         : 3.950e-02
//                          :   14 : pTjjMax          : 3.652e-02
//                          :   15 : pTtot            : 3.202e-02
//                          :   16 : DiBJetDeltaPhi   : 2.791e-02
//                          :   17 : DiLeptonPt       : 2.467e-02
//                          :   18 : Lepton0Eta       : 2.304e-02
//                          :   19 : Lepton1Pt        : 1.625e-02
//                          :   20 : BJet0Eta         : 1.493e-02
//                          :   21 : Lepton1Eta       : 1.436e-02
//                          :   22 : BJet1Pt          : 9.940e-03
//                          :   23 : BJet1Eta         : 7.494e-03
//                          :   24 : deltaphijjmax    : 5.672e-03
//                          :   25 : deltaetajj       : 2.563e-03
//                          : -----------------------------------------
// Factory                  : Train method: BDT for Classification
//                          :
// <WARNING>                : Events with negative event weights are USED during the BDT training. This might cause problems with small node sizes or with the boosting. Please remove negative events from training using the option *IgnoreEventsWithNegWeightsInTraining* in case you observe problems with the boosting
// BDT                      : #events: (reweighted) sig: 238248 bkg: 238248
//                          : #events: (unweighted) sig: 8990 bkg: 467506
//                          : Training 300 Decision Trees ... patience please
//                          : Elapsed time for training with 476496 events: 214 sec
// BDT                      : [dataset] : Evaluation of BDT on training sample (476496 events)
//                          : Elapsed time for evaluation of 476496 events: 13 sec
//                          : Creating xml weight file: dataset/weights/TMVA_Higgs_Classification_BDT.weights.xml
//                          : Creating standalone class: dataset/weights/TMVA_Higgs_Classification_BDT.class.C
//                          : Higgs_ClassificationOutputVBFbkg.root:/dataset/Method_BDT/BDT
// Factory                  : Training finished
//                          :
//                          : Ranking input variables (method specific)...
// BDT                      : Ranking result (top variable is best ranked)
//                          : --------------------------------------------------
//                          : Rank : Variable         : Variable Importance
//                          : --------------------------------------------------
//                          :    1 : DiBJetMass       : 7.289e-02
//                          :    2 : Lepton0Eta       : 5.594e-02
//                          :    3 : DiLeptonMass     : 5.299e-02
//                          :    4 : Mtot             : 4.992e-02
//                          :    5 : KLF_mtop         : 4.776e-02
//                          :    6 : BJet1Eta         : 4.738e-02
//                          :    7 : minDbl           : 4.721e-02
//                          :    8 : BJet0Eta         : 4.652e-02
//                          :    9 : MTHiggs          : 4.479e-02
//                          :   10 : DiBJetDeltaR     : 4.207e-02
//                          :   11 : minDRlj1         : 3.929e-02
//                          :   12 : DiBJetDeltaPhi   : 3.845e-02
//                          :   13 : minDRlj2         : 3.808e-02
//                          :   14 : Lepton1Eta       : 3.778e-02
//                          :   15 : deltaphijjmax    : 3.519e-02
//                          :   16 : pTtot            : 3.486e-02
//                          :   17 : DiBJetPt         : 3.465e-02
//                          :   18 : DiLeptonDeltaPhi : 3.431e-02
//                          :   19 : MjjMax           : 3.325e-02
//                          :   20 : deltaetajj       : 3.266e-02
//                          :   21 : Lepton1Pt        : 2.826e-02
//                          :   22 : DiLeptonPt       : 2.824e-02
//                          :   23 : NOtherJets       : 2.724e-02
//                          :   24 : pTjjMax          : 2.706e-02
//                          :   25 : BJet1Pt          : 2.319e-02
//                          : --------------------------------------------------
// Factory                  : === Destroy and recreate all methods via weight files for testing ===
//                          :
//                          : Reading weight file: dataset/weights/TMVA_Higgs_Classification_BDT.weights.xml

// %% [markdown]
// ## Test  all methods
//
// Here we test all methods using the test data set

// %%
factory.TestAllMethods();
// Out:
// Factory                  : Test all methods
// Factory                  : Test method: BDT for Classification performance
//                          :
// BDT                      : [dataset] : Evaluation of BDT on testing sample (1427870 events)
//                          : Elapsed time for evaluation of 1427870 events: 32.4 sec

// %% [raw]
// ## Evaluate all methods
//
// Here we evaluate all methods and compare their performances, computing efficiencies, ROC curves etc.. using both training and tetsing data sets. Several histograms are produced which can be examined with the TMVAGui or directly using the output file

// %%
factory.EvaluateAllMethods();
// Out:
// Factory                  : Evaluate all methods
// Factory                  : Evaluate classifier: BDT
//                          :
// BDT                      : [dataset] : Loop over test events and fill histograms with classifier response...
//                          :
// TFHandler_BDT            :         Variable                Mean                RMS        [        Min                Max ]
//                          : ---------------------------------------------------------------------------------------------------
//                          :     DiLeptonMass:            50626.            21643.   [            15000.        1.1000e+05 ]
//                          :       DiLeptonPt:            78018.            48708.   [            90.325        1.5894e+06 ]
//                          : DiLeptonDeltaPhi:         0.0045655            1.4688   [           -3.1416            3.1416 ]
//                          :           MjjMax:        1.3990e+06        7.2414e+05   [        6.0000e+05        9.7542e+06 ]
//                          :       deltaetajj:            6.3390            1.1167   [            4.0000            9.5067 ]
//                          :          pTjjMax:        1.1049e+05            88343.   [            24.357        2.0910e+06 ]
//                          :    deltaphijjmax:         0.0027142            2.5655   [           -6.2752            6.2739 ]
//                          :        Lepton1Pt:            28222.            15972.   [            9000.1        5.3349e+05 ]
//                          :       Lepton1Eta:         0.0060639            1.1705   [           -2.6997            2.6998 ]
//                          :          BJet1Pt:            53223.            28821.   [            20000.        9.3370e+05 ]
//                          :         BJet1Eta:         0.0057406            1.1855   [           -2.5000            2.5000 ]
//                          :       Lepton0Eta:         0.0061958            1.1272   [           -2.6977            2.6987 ]
//                          :         BJet0Eta:       -0.00079216            1.1341   [           -2.5000            2.5000 ]
//                          :             Mtot:        1.6229e+06        8.5847e+05   [        2.2799e+05        9.1250e+06 ]
//                          :          MTHiggs:        1.4756e+05            61589.   [            16568.        2.3645e+06 ]
//                          :       DiBJetMass:        1.3117e+05            77899.   [            9375.3        3.0582e+06 ]
//                          :         DiBJetPt:        1.1162e+05            76877.   [            20.635        1.6290e+06 ]
//                          :     DiBJetDeltaR:            2.0662           0.82056   [           0.35845            5.7365 ]
//                          :   DiBJetDeltaPhi:          0.012947            1.8877   [           -3.1416            3.1416 ]
//                          :         minDRlj1:            2.1635           0.87359   [           0.38320            5.2735 ]
//                          :         minDRlj2:            2.0995           0.86256   [           0.37906            5.3595 ]
//                          :            pTtot:            85564.            58703.   [            65.200        1.3235e+06 ]
//                          :           minDbl:            2.3667           0.91143   [           0.38878            5.8098 ]
//                          :         KLF_mtop:            162.79            291.95   [           -999.00            700.00 ]
//                          :       NOtherJets:            4.1764            1.9495   [            2.0000            58.000 ]
//                          : ---------------------------------------------------------------------------------------------------
//                          :
//                          : <PlotVariables> Will not produce scatter plots ==>
//                          : |  The number of 25 input variables and 0 target values would require 300 two-dimensional
//                          : |  histograms, which would occupy the computer's memory. Note that this
//                          : |  suppression does not have any consequences for your analysis, other
//                          : |  than not disposing of these scatter plots. You can modify the maximum
//                          : |  number of input variables allowed to generate scatter plots in your
//                          : |  script via the command line:
//                          : |  "(TMVA::gConfig().GetVariablePlotting()).fMaxNumOfAllowedVariablesForScatterPlots = <some int>;"
//                          :
//                          : Some more output
//                          :
//                          : Evaluation results ranked by best signal efficiency and purity (area)
//                          : -------------------------------------------------------------------------------------------------------------------
//                          : DataSet       MVA
//                          : Name:         Method:          ROC-integ
//                          : dataset       BDT            : 0.966
//                          : -------------------------------------------------------------------------------------------------------------------
//                          :
//                          : Testing efficiency compared to training efficiency (overtraining check)
//                          : -------------------------------------------------------------------------------------------------------------------
//                          : DataSet              MVA              Signal efficiency: from test sample (from training sample)
//                          : Name:                Method:          @B=0.01             @B=0.10            @B=0.30
//                          : -------------------------------------------------------------------------------------------------------------------
//                          : dataset              BDT            : 0.615 (0.620)       0.898 (0.897)      0.978 (0.977)
//                          : -------------------------------------------------------------------------------------------------------------------
//                          :
// Dataset:dataset          : Created tree 'TestTree' with 1427870 events
//                          :
// Dataset:dataset          : Created tree 'TrainTree' with 476496 events
//                          :
// Factory                  : Thank you for using TMVA!
//                          : For citation information, please visit: http://tmva.sf.net/citeTMVA.html

// %% [markdown]
// ## Plot ROC Curve
// We enable JavaScript visualisation for the plots

// %%
c1 = factory.GetROCCurve(loader);
c1->Draw();

// %% [markdown]
// ####  Close outputfile to save all output information (evaluation result of methods)

// %%
outputFile->Close();
