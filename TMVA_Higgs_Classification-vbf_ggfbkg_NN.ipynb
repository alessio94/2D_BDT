// %% [markdown]
// <img src="tmva_logo.gif" height="20%" width="20%">
//
// # TMVA Classification Example

// %% [markdown]
// ## Declare Factory
//
// Create the Factory class. Later you can choose the methods
// whose performance you'd like to investigate.
//
// The factory is the major TMVA object you have to interact with. Here is the list of parameters you need to pass
//
//  - The first argument is the base of the name of all the output
// weightfiles in the directory weight/ that will be created with the
// method parameters
//
//  - The second argument is the output file for the training results
//
//  - The third argument is a string option defining some general configuration for the TMVA session. For example all TMVA output can be suppressed by removing the "!" (not) in front of the "Silent" argument in the option string

// %%
TMVA::Tools::Instance();


auto outputFile = TFile::Open("Higgs_ClassificationOutputVBFbkgNN.root", "RECREATE");

TMVA::Factory factory("TMVA_Higgs_Classification", outputFile,
                      "!V:ROC:!Silent:Color:!DrawProgressBar:AnalysisType=Classification" );

// %% [markdown]
// ## Setup Dataset(s)
//
// Define input data file and signal and background trees

// %%
TString inputFileName1 = "vbf_trainNN.root";
TString inputFileName2 = "vbf_testNN.root";
TString inputFileName3 = "ggfbkg_trainNN.root";
TString inputFileName4 = "ggfbkg_testNN.root";


//{
//   TChain chain("h42");
//   chain.Add("ggf_train.root");
//    tree = (TTree)f1->Get(“myEvent”);
//tree->SetWeight(0.4);
//   chain.Add("bkg_train.root");
//}


//TString inputFileName = "tmva_class_example.root";

auto inputFile1 = TFile::Open( inputFileName1 );
auto inputFile2 = TFile::Open( inputFileName2 );
auto inputFile3 = TFile::Open( inputFileName3 );
auto inputFile4 = TFile::Open( inputFileName4 );


// --- Register the training and test trees

//TTree *signalTree     = (TTree*)inputFile1->Get("TF");
//TTree *backgroundTree = (TTree*)inputFile2->Get("TF");

TTree *signalTreeTrain     = (TTree*)inputFile1->Get("test");
TTree *signalTreeTest     = (TTree*)inputFile2->Get("test");
TTree *backgroundTreeTrain = (TTree*)inputFile3->Get("test");
TTree *backgroundTreeTest = (TTree*)inputFile4->Get("test");


signalTreeTrain->Print();
signalTreeTest->Print();
backgroundTreeTrain->Print();
backgroundTreeTest->Print();

 TH1F *hist1=new TH1F("hist_bkg","",1,-100000000000000000,10000000000000);
 backgroundTreeTest->Draw("weight>>hist_bkg");
 double weight_bkg_total = hist1->GetMean()*hist1->GetEntries();

  string weight_bkg = "weight/"+ std::to_string(weight_bkg_total);

  cout<<" w bkg:   "<<weight_bkg <<endl;

 TH1F *hist2=new TH1F("hist_sig","",1,-100000000000000000,10000000000000);
 signalTreeTest->Draw("weight>>hist_sig");
 double weight_sig_total = hist2->GetMean()*hist2->GetEntries();

  string weight_sig = "weight/"+ std::to_string(weight_sig_total);

  cout<<" w sig:   "<<weight_sig <<endl;
// Out:
// ******************************************************************************
// *Tree    :test      : bbll_ee                                                *
// *Entries :     8990 : Total =         1903881 bytes  File  Size =    1499082 *
// *        :          : Tree compression factor =   1.26                       *
// ******************************************************************************
// *Br    0 :process_id : process_id/I                                          *
// *Entries :     8990 : Total  Size=      36615 bytes  File Size  =        460 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=  78.50     *
// *............................................................................*
// *Br    1 :is_sf     : is_sf/I                                                *
// *Entries :     8990 : Total  Size=      36585 bytes  File Size  =        401 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=  90.02     *
// *............................................................................*
// *Br    2 :is_ee     : is_ee/I                                                *
// *Entries :     8990 : Total  Size=      36585 bytes  File Size  =        379 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=  95.25     *
// *............................................................................*
// *Br    3 :is_em     : is_em/I                                                *
// *Entries :     8990 : Total  Size=      36585 bytes  File Size  =        381 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=  94.75     *
// *............................................................................*
// *Br    4 :ll_m      : ll_m/F                                                 *
// *Entries :     8990 : Total  Size=      36579 bytes  File Size  =      31977 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br    5 :bb_m      : bb_m/F                                                 *
// *Entries :     8990 : Total  Size=      36579 bytes  File Size  =      31597 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br    6 :m_bl      : m_bl/F                                                 *
// *Entries :     8990 : Total  Size=      36579 bytes  File Size  =      32189 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br    7 :yield     : yield/I                                                *
// *Entries :     8990 : Total  Size=      36585 bytes  File Size  =        387 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=  93.28     *
// *............................................................................*
// *Br    8 :bdt_1d    : bdt_1d/F                                               *
// *Entries :     8990 : Total  Size=      36591 bytes  File Size  =      33012 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.09     *
// *............................................................................*
// *Br    9 :event_number : event_number/l                                      *
// *Entries :     8990 : Total  Size=      72672 bytes  File Size  =      25881 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   2.79     *
// *............................................................................*
// *Br   10 :vbf_0_eta : vbf_0_eta/F                                            *
// *Entries :     8990 : Total  Size=      36609 bytes  File Size  =      32878 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.10     *
// *............................................................................*
// *Br   11 :vbf_1_eta : vbf_1_eta/F                                            *
// *Entries :     8990 : Total  Size=      36609 bytes  File Size  =      32756 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.10     *
// *............................................................................*
// *Br   12 :vbf_jet_1_pt : vbf_jet_1_pt/F                                      *
// *Entries :     8990 : Total  Size=      36627 bytes  File Size  =      31683 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   13 :vbf_dijets_DEta : vbf_dijets_DEta/F                                *
// *Entries :     8990 : Total  Size=      36645 bytes  File Size  =      33439 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   14 :vbf_Dijets_Mass : vbf_Dijets_Mass/F                                *
// *Entries :     8990 : Total  Size=      36645 bytes  File Size  =      31513 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   15 :vbf_bjet_0_eta : vbf_bjet_0_eta/F                                  *
// *Entries :     8990 : Total  Size=      36639 bytes  File Size  =      33522 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   16 :vbf_m_bbll : vbf_m_bbll/F                                          *
// *Entries :     8990 : Total  Size=      36615 bytes  File Size  =      31742 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   17 :vbf_deltar_min_bl : vbf_deltar_min_bl/F                            *
// *Entries :     8990 : Total  Size=      36657 bytes  File Size  =      32160 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   18 :vbf_lept_0_eta : vbf_lept_0_eta/F                                  *
// *Entries :     8990 : Total  Size=      36639 bytes  File Size  =      33460 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   19 :vbf_m_bbllmet : vbf_m_bbllmet/F                                    *
// *Entries :     8990 : Total  Size=      36633 bytes  File Size  =      32015 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   20 :vbf_lept_1_eta : vbf_lept_1_eta/F                                  *
// *Entries :     8990 : Total  Size=      36639 bytes  File Size  =      33509 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   21 :vbf_bb_deltar : vbf_bb_deltar/F                                    *
// *Entries :     8990 : Total  Size=      36633 bytes  File Size  =      32100 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   22 :vbf_bjet_1_eta : vbf_bjet_1_eta/F                                  *
// *Entries :     8990 : Total  Size=      36639 bytes  File Size  =      33519 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   23 :vbf_bb_pt : vbf_bb_pt/F                                            *
// *Entries :     8990 : Total  Size=      36609 bytes  File Size  =      32465 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.11     *
// *............................................................................*
// *Br   24 :vbf_bjet_0_pt : vbf_bjet_0_pt/F                                    *
// *Entries :     8990 : Total  Size=      36633 bytes  File Size  =      32087 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   25 :vbf_bjet_1_pt : vbf_bjet_1_pt/F                                    *
// *Entries :     8990 : Total  Size=      36633 bytes  File Size  =      32117 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   26 :vbf_ll_deltaphi : vbf_ll_deltaphi/F                                *
// *Entries :     8990 : Total  Size=      36645 bytes  File Size  =      33507 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   27 :vbf_m_ttbar : vbf_m_ttbar/F                                        *
// *Entries :     8990 : Total  Size=      36621 bytes  File Size  =      30663 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.18     *
// *............................................................................*
// *Br   28 :vbf_0_phi : vbf_0_phi/F                                            *
// *Entries :     8990 : Total  Size=      36609 bytes  File Size  =      33504 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   29 :vbf_bjet_0_phi : vbf_bjet_0_phi/F                                  *
// *Entries :     8990 : Total  Size=      36639 bytes  File Size  =      33504 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   30 :vbf_sum_met_ptll : vbf_sum_met_ptll/F                              *
// *Entries :     8990 : Total  Size=      36651 bytes  File Size  =      32146 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   31 :vbf_lept_1_phi : vbf_lept_1_phi/F                                  *
// *Entries :     8990 : Total  Size=      36639 bytes  File Size  =      33533 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   32 :vbf_lept_1_pt : vbf_lept_1_pt/F                                    *
// *Entries :     8990 : Total  Size=      36633 bytes  File Size  =      32056 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   33 :vbf_met_met : vbf_met_met/F                                        *
// *Entries :     8990 : Total  Size=      36621 bytes  File Size  =      32461 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.11     *
// *............................................................................*
// *Br   34 :vbf_mcoll : vbf_mcoll/F                                            *
// *Entries :     8990 : Total  Size=      36609 bytes  File Size  =      33507 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   35 :vbf_dphi_met_ll : vbf_dphi_met_ll/F                                *
// *Entries :     8990 : Total  Size=      36645 bytes  File Size  =      33895 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.07     *
// *............................................................................*
// *Br   36 :vbf_bjet_1_phi : vbf_bjet_1_phi/F                                  *
// *Entries :     8990 : Total  Size=      36639 bytes  File Size  =      33536 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   37 :vbf_ll_m  : vbf_ll_m/F                                             *
// *Entries :     8990 : Total  Size=      36603 bytes  File Size  =      32024 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   38 :vbf_1_phi : vbf_1_phi/F                                            *
// *Entries :     8990 : Total  Size=      36609 bytes  File Size  =      33517 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   39 :vbf_met_phi_centrality : vbf_met_phi_centrality/F                  *
// *Entries :     8990 : Total  Size=      36687 bytes  File Size  =      33173 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.09     *
// *............................................................................*
// *Br   40 :vbf_bb_deltaphi : vbf_bb_deltaphi/F                                *
// *Entries :     8990 : Total  Size=      36645 bytes  File Size  =      33370 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   41 :vbf_lept_0_pt : vbf_lept_0_pt/F                                    *
// *Entries :     8990 : Total  Size=      36633 bytes  File Size  =      32108 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   42 :vbf_ll_pt : vbf_ll_pt/F                                            *
// *Entries :     8990 : Total  Size=      36609 bytes  File Size  =      32294 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   43 :vbf_lept_0_phi : vbf_lept_0_phi/F                                  *
// *Entries :     8990 : Total  Size=      36639 bytes  File Size  =      33523 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   44 :vbf_m_t2_bb : vbf_m_t2_bb/F                                        *
// *Entries :     8990 : Total  Size=      36621 bytes  File Size  =      32823 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.10     *
// *............................................................................*
// *Br   45 :vbf_mmc_minu3p : vbf_mmc_minu3p/F                                  *
// *Entries :     8990 : Total  Size=      36639 bytes  File Size  =      26766 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.35     *
// *............................................................................*
// *Br   46 :vbf_pt_bbllmet_vector : vbf_pt_bbllmet_vector/F                    *
// *Entries :     8990 : Total  Size=      36681 bytes  File Size  =      32032 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   47 :vbf_pt_bbll_vector : vbf_pt_bbll_vector/F                          *
// *Entries :     8990 : Total  Size=      36663 bytes  File Size  =      31758 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   48 :bdt_cvv0  : bdt_cvv0/F                                             *
// *Entries :     8990 : Total  Size=      36603 bytes  File Size  =      33405 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   49 :weight    : weight/D                                               *
// *Entries :     8990 : Total  Size=      72630 bytes  File Size  =      68243 *
// *Baskets :        3 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// ******************************************************************************
// *Tree    :test      : bbll_ee                                                *
// *Entries :    27314 : Total =         5723215 bytes  File  Size =    4533870 *
// *        :          : Tree compression factor =   1.26                       *
// ******************************************************************************
// *Br    0 :process_id : process_id/I                                          *
// *Entries :    27314 : Total  Size=     110061 bytes  File Size  =       1047 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression= 104.64     *
// *............................................................................*
// *Br    1 :is_sf     : is_sf/I                                                *
// *Entries :    27314 : Total  Size=     110021 bytes  File Size  =        947 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression= 115.67     *
// *............................................................................*
// *Br    2 :is_ee     : is_ee/I                                                *
// *Entries :    27314 : Total  Size=     110021 bytes  File Size  =        913 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression= 119.97     *
// *............................................................................*
// *Br    3 :is_em     : is_em/I                                                *
// *Entries :    27314 : Total  Size=     110021 bytes  File Size  =        928 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression= 118.03     *
// *............................................................................*
// *Br    4 :ll_m      : ll_m/F                                                 *
// *Entries :    27314 : Total  Size=     110013 bytes  File Size  =      96907 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br    5 :bb_m      : bb_m/F                                                 *
// *Entries :    27314 : Total  Size=     110013 bytes  File Size  =      95682 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br    6 :m_bl      : m_bl/F                                                 *
// *Entries :    27314 : Total  Size=     110013 bytes  File Size  =      97574 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br    7 :yield     : yield/I                                                *
// *Entries :    27314 : Total  Size=     110021 bytes  File Size  =        955 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression= 114.70     *
// *............................................................................*
// *Br    8 :bdt_1d    : bdt_1d/F                                               *
// *Entries :    27314 : Total  Size=     110029 bytes  File Size  =     100135 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.09     *
// *............................................................................*
// *Br    9 :event_number : event_number/l                                      *
// *Entries :    27314 : Total  Size=     219572 bytes  File Size  =      80023 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   2.74     *
// *............................................................................*
// *Br   10 :vbf_0_eta : vbf_0_eta/F                                            *
// *Entries :    27314 : Total  Size=     110053 bytes  File Size  =      99696 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.10     *
// *............................................................................*
// *Br   11 :vbf_1_eta : vbf_1_eta/F                                            *
// *Entries :    27314 : Total  Size=     110053 bytes  File Size  =      99230 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.10     *
// *............................................................................*
// *Br   12 :vbf_jet_1_pt : vbf_jet_1_pt/F                                      *
// *Entries :    27314 : Total  Size=     110077 bytes  File Size  =      96099 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   13 :vbf_dijets_DEta : vbf_dijets_DEta/F                                *
// *Entries :    27314 : Total  Size=     110101 bytes  File Size  =     101222 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   14 :vbf_Dijets_Mass : vbf_Dijets_Mass/F                                *
// *Entries :    27314 : Total  Size=     110101 bytes  File Size  =      95459 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   15 :vbf_bjet_0_eta : vbf_bjet_0_eta/F                                  *
// *Entries :    27314 : Total  Size=     110093 bytes  File Size  =     101464 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   16 :vbf_m_bbll : vbf_m_bbll/F                                          *
// *Entries :    27314 : Total  Size=     110061 bytes  File Size  =      96221 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   17 :vbf_deltar_min_bl : vbf_deltar_min_bl/F                            *
// *Entries :    27314 : Total  Size=     110117 bytes  File Size  =      97347 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   18 :vbf_lept_0_eta : vbf_lept_0_eta/F                                  *
// *Entries :    27314 : Total  Size=     110093 bytes  File Size  =     101412 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   19 :vbf_m_bbllmet : vbf_m_bbllmet/F                                    *
// *Entries :    27314 : Total  Size=     110085 bytes  File Size  =      96971 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   20 :vbf_lept_1_eta : vbf_lept_1_eta/F                                  *
// *Entries :    27314 : Total  Size=     110093 bytes  File Size  =     101557 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   21 :vbf_bb_deltar : vbf_bb_deltar/F                                    *
// *Entries :    27314 : Total  Size=     110085 bytes  File Size  =      97291 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   22 :vbf_bjet_1_eta : vbf_bjet_1_eta/F                                  *
// *Entries :    27314 : Total  Size=     110093 bytes  File Size  =     101517 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   23 :vbf_bb_pt : vbf_bb_pt/F                                            *
// *Entries :    27314 : Total  Size=     110053 bytes  File Size  =      98479 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.11     *
// *............................................................................*
// *Br   24 :vbf_bjet_0_pt : vbf_bjet_0_pt/F                                    *
// *Entries :    27314 : Total  Size=     110085 bytes  File Size  =      97209 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   25 :vbf_bjet_1_pt : vbf_bjet_1_pt/F                                    *
// *Entries :    27314 : Total  Size=     110085 bytes  File Size  =      97334 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   26 :vbf_ll_deltaphi : vbf_ll_deltaphi/F                                *
// *Entries :    27314 : Total  Size=     110101 bytes  File Size  =     101549 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   27 :vbf_m_ttbar : vbf_m_ttbar/F                                        *
// *Entries :    27314 : Total  Size=     110069 bytes  File Size  =      92848 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.18     *
// *............................................................................*
// *Br   28 :vbf_0_phi : vbf_0_phi/F                                            *
// *Entries :    27314 : Total  Size=     110053 bytes  File Size  =     101539 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   29 :vbf_bjet_0_phi : vbf_bjet_0_phi/F                                  *
// *Entries :    27314 : Total  Size=     110093 bytes  File Size  =     101552 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   30 :vbf_sum_met_ptll : vbf_sum_met_ptll/F                              *
// *Entries :    27314 : Total  Size=     110109 bytes  File Size  =      97406 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   31 :vbf_lept_1_phi : vbf_lept_1_phi/F                                  *
// *Entries :    27314 : Total  Size=     110093 bytes  File Size  =     101608 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   32 :vbf_lept_1_pt : vbf_lept_1_pt/F                                    *
// *Entries :    27314 : Total  Size=     110085 bytes  File Size  =      97084 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   33 :vbf_met_met : vbf_met_met/F                                        *
// *Entries :    27314 : Total  Size=     110069 bytes  File Size  =      98369 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.11     *
// *............................................................................*
// *Br   34 :vbf_mcoll : vbf_mcoll/F                                            *
// *Entries :    27314 : Total  Size=     110053 bytes  File Size  =     101513 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   35 :vbf_dphi_met_ll : vbf_dphi_met_ll/F                                *
// *Entries :    27314 : Total  Size=     110101 bytes  File Size  =     102562 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.07     *
// *............................................................................*
// *Br   36 :vbf_bjet_1_phi : vbf_bjet_1_phi/F                                  *
// *Entries :    27314 : Total  Size=     110093 bytes  File Size  =     101574 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   37 :vbf_ll_m  : vbf_ll_m/F                                             *
// *Entries :    27314 : Total  Size=     110045 bytes  File Size  =      96979 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   38 :vbf_1_phi : vbf_1_phi/F                                            *
// *Entries :    27314 : Total  Size=     110053 bytes  File Size  =     101514 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   39 :vbf_met_phi_centrality : vbf_met_phi_centrality/F                  *
// *Entries :    27314 : Total  Size=     110157 bytes  File Size  =     100313 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.09     *
// *............................................................................*
// *Br   40 :vbf_bb_deltaphi : vbf_bb_deltaphi/F                                *
// *Entries :    27314 : Total  Size=     110101 bytes  File Size  =     101107 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   41 :vbf_lept_0_pt : vbf_lept_0_pt/F                                    *
// *Entries :    27314 : Total  Size=     110085 bytes  File Size  =      97295 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   42 :vbf_ll_pt : vbf_ll_pt/F                                            *
// *Entries :    27314 : Total  Size=     110053 bytes  File Size  =      97885 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   43 :vbf_lept_0_phi : vbf_lept_0_phi/F                                  *
// *Entries :    27314 : Total  Size=     110093 bytes  File Size  =     101535 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   44 :vbf_m_t2_bb : vbf_m_t2_bb/F                                        *
// *Entries :    27314 : Total  Size=     110069 bytes  File Size  =      99392 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.10     *
// *............................................................................*
// *Br   45 :vbf_mmc_minu3p : vbf_mmc_minu3p/F                                  *
// *Entries :    27314 : Total  Size=     110093 bytes  File Size  =      80396 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.36     *
// *............................................................................*
// *Br   46 :vbf_pt_bbllmet_vector : vbf_pt_bbllmet_vector/F                    *
// *Entries :    27314 : Total  Size=     110149 bytes  File Size  =      97003 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   47 :vbf_pt_bbll_vector : vbf_pt_bbll_vector/F                          *
// *Entries :    27314 : Total  Size=     110125 bytes  File Size  =      96255 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   48 :bdt_cvv0  : bdt_cvv0/F                                             *
// *Entries :    27314 : Total  Size=     110045 bytes  File Size  =     101287 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   49 :weight    : weight/D                                               *
// *Entries :    27314 : Total  Size=     219506 bytes  File Size  =     206638 *
// *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
// ******************************************************************************
// *Tree    :test      : bbll_ee                                                *
// *Entries :   484305 : Total =       100785177 bytes  File  Size =   80018318 *
// *        :          : Tree compression factor =   1.26                       *
// ******************************************************************************
// *Br    0 :process_id : process_id/I                                          *
// *Entries :   484305 : Total  Size=    1938175 bytes  File Size  =      10515 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression= 184.28     *
// *............................................................................*
// *Br    1 :is_sf     : is_sf/I                                                *
// *Entries :   484305 : Total  Size=    1938125 bytes  File Size  =       9673 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression= 200.31     *
// *............................................................................*
// *Br    2 :is_ee     : is_ee/I                                                *
// *Entries :   484305 : Total  Size=    1938125 bytes  File Size  =       9394 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression= 206.26     *
// *............................................................................*
// *Br    3 :is_em     : is_em/I                                                *
// *Entries :   484305 : Total  Size=    1938125 bytes  File Size  =       9642 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression= 200.96     *
// *............................................................................*
// *Br    4 :ll_m      : ll_m/F                                                 *
// *Entries :   484305 : Total  Size=    1938115 bytes  File Size  =    1702390 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br    5 :bb_m      : bb_m/F                                                 *
// *Entries :   484305 : Total  Size=    1938115 bytes  File Size  =    1731431 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br    6 :m_bl      : m_bl/F                                                 *
// *Entries :   484305 : Total  Size=    1938115 bytes  File Size  =    1704137 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br    7 :yield     : yield/I                                                *
// *Entries :   484305 : Total  Size=    1938125 bytes  File Size  =      10022 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression= 193.34     *
// *............................................................................*
// *Br    8 :bdt_1d    : bdt_1d/F                                               *
// *Entries :   484305 : Total  Size=    1938135 bytes  File Size  =    1735341 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br    9 :event_number : event_number/l                                      *
// *Entries :   484305 : Total  Size=    3875751 bytes  File Size  =    1791917 *
// *Baskets :       10 : Basket Size=      32000 bytes  Compression=   2.16     *
// *............................................................................*
// *Br   10 :vbf_0_eta : vbf_0_eta/F                                            *
// *Entries :   484305 : Total  Size=    1938165 bytes  File Size  =    1794138 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   11 :vbf_1_eta : vbf_1_eta/F                                            *
// *Entries :   484305 : Total  Size=    1938165 bytes  File Size  =    1790434 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   12 :vbf_jet_1_pt : vbf_jet_1_pt/F                                      *
// *Entries :   484305 : Total  Size=    1938195 bytes  File Size  =    1709864 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   13 :vbf_dijets_DEta : vbf_dijets_DEta/F                                *
// *Entries :   484305 : Total  Size=    1938225 bytes  File Size  =    1797828 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   14 :vbf_Dijets_Mass : vbf_Dijets_Mass/F                                *
// *Entries :   484305 : Total  Size=    1938225 bytes  File Size  =    1731677 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   15 :vbf_bjet_0_eta : vbf_bjet_0_eta/F                                  *
// *Entries :   484305 : Total  Size=    1938215 bytes  File Size  =    1797071 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   16 :vbf_m_bbll : vbf_m_bbll/F                                          *
// *Entries :   484305 : Total  Size=    1938175 bytes  File Size  =    1689452 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   17 :vbf_deltar_min_bl : vbf_deltar_min_bl/F                            *
// *Entries :   484305 : Total  Size=    1938245 bytes  File Size  =    1714084 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   18 :vbf_lept_0_eta : vbf_lept_0_eta/F                                  *
// *Entries :   484305 : Total  Size=    1938215 bytes  File Size  =    1795486 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   19 :vbf_m_bbllmet : vbf_m_bbllmet/F                                    *
// *Entries :   484305 : Total  Size=    1938205 bytes  File Size  =    1698325 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   20 :vbf_lept_1_eta : vbf_lept_1_eta/F                                  *
// *Entries :   484305 : Total  Size=    1938215 bytes  File Size  =    1797010 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   21 :vbf_bb_deltar : vbf_bb_deltar/F                                    *
// *Entries :   484305 : Total  Size=    1938205 bytes  File Size  =    1716287 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   22 :vbf_bjet_1_eta : vbf_bjet_1_eta/F                                  *
// *Entries :   484305 : Total  Size=    1938215 bytes  File Size  =    1797451 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   23 :vbf_bb_pt : vbf_bb_pt/F                                            *
// *Entries :   484305 : Total  Size=    1938165 bytes  File Size  =    1736138 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   24 :vbf_bjet_0_pt : vbf_bjet_0_pt/F                                    *
// *Entries :   484305 : Total  Size=    1938205 bytes  File Size  =    1720616 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   25 :vbf_bjet_1_pt : vbf_bjet_1_pt/F                                    *
// *Entries :   484305 : Total  Size=    1938205 bytes  File Size  =    1723035 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   26 :vbf_ll_deltaphi : vbf_ll_deltaphi/F                                *
// *Entries :   484305 : Total  Size=    1938225 bytes  File Size  =    1792513 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   27 :vbf_m_ttbar : vbf_m_ttbar/F                                        *
// *Entries :   484305 : Total  Size=    1938185 bytes  File Size  =    1654687 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.17     *
// *............................................................................*
// *Br   28 :vbf_0_phi : vbf_0_phi/F                                            *
// *Entries :   484305 : Total  Size=    1938165 bytes  File Size  =    1795508 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   29 :vbf_bjet_0_phi : vbf_bjet_0_phi/F                                  *
// *Entries :   484305 : Total  Size=    1938215 bytes  File Size  =    1795593 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   30 :vbf_sum_met_ptll : vbf_sum_met_ptll/F                              *
// *Entries :   484305 : Total  Size=    1938235 bytes  File Size  =    1717128 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   31 :vbf_lept_1_phi : vbf_lept_1_phi/F                                  *
// *Entries :   484305 : Total  Size=    1938215 bytes  File Size  =    1795836 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   32 :vbf_lept_1_pt : vbf_lept_1_pt/F                                    *
// *Entries :   484305 : Total  Size=    1938205 bytes  File Size  =    1717552 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   33 :vbf_met_met : vbf_met_met/F                                        *
// *Entries :   484305 : Total  Size=    1938185 bytes  File Size  =    1737706 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   34 :vbf_mcoll : vbf_mcoll/F                                            *
// *Entries :   484305 : Total  Size=    1938165 bytes  File Size  =    1811842 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.07     *
// *............................................................................*
// *Br   35 :vbf_dphi_met_ll : vbf_dphi_met_ll/F                                *
// *Entries :   484305 : Total  Size=    1938225 bytes  File Size  =    1794583 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   36 :vbf_bjet_1_phi : vbf_bjet_1_phi/F                                  *
// *Entries :   484305 : Total  Size=    1938215 bytes  File Size  =    1795864 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   37 :vbf_ll_m  : vbf_ll_m/F                                             *
// *Entries :   484305 : Total  Size=    1938155 bytes  File Size  =    1703155 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   38 :vbf_1_phi : vbf_1_phi/F                                            *
// *Entries :   484305 : Total  Size=    1938165 bytes  File Size  =    1795285 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   39 :vbf_met_phi_centrality : vbf_met_phi_centrality/F                  *
// *Entries :   484305 : Total  Size=    1938295 bytes  File Size  =    1792924 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   40 :vbf_bb_deltaphi : vbf_bb_deltaphi/F                                *
// *Entries :   484305 : Total  Size=    1938225 bytes  File Size  =    1782154 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.09     *
// *............................................................................*
// *Br   41 :vbf_lept_0_pt : vbf_lept_0_pt/F                                    *
// *Entries :   484305 : Total  Size=    1938205 bytes  File Size  =    1714497 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   42 :vbf_ll_pt : vbf_ll_pt/F                                            *
// *Entries :   484305 : Total  Size=    1938165 bytes  File Size  =    1727696 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   43 :vbf_lept_0_phi : vbf_lept_0_phi/F                                  *
// *Entries :   484305 : Total  Size=    1938215 bytes  File Size  =    1795891 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   44 :vbf_m_t2_bb : vbf_m_t2_bb/F                                        *
// *Entries :   484305 : Total  Size=    1938185 bytes  File Size  =    1742481 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.11     *
// *............................................................................*
// *Br   45 :vbf_mmc_minu3p : vbf_mmc_minu3p/F                                  *
// *Entries :   484305 : Total  Size=    1938215 bytes  File Size  =    1034945 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.87     *
// *............................................................................*
// *Br   46 :vbf_pt_bbllmet_vector : vbf_pt_bbllmet_vector/F                    *
// *Entries :   484305 : Total  Size=    1938285 bytes  File Size  =    1698372 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   47 :vbf_pt_bbll_vector : vbf_pt_bbll_vector/F                          *
// *Entries :   484305 : Total  Size=    1938255 bytes  File Size  =    1689499 *
// *Baskets :        6 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// ...
// *Br    0 :process_id : process_id/I                                          *
// *Entries :  1451490 : Total  Size=    5807710 bytes  File Size  =      30350 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression= 191.34     *
// *............................................................................*
// *Br    1 :is_sf     : is_sf/I                                                *
// *Entries :  1451490 : Total  Size=    5807615 bytes  File Size  =      28260 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression= 205.49     *
// *............................................................................*
// *Br    2 :is_ee     : is_ee/I                                                *
// *Entries :  1451490 : Total  Size=    5807615 bytes  File Size  =      27460 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression= 211.47     *
// *............................................................................*
// *Br    3 :is_em     : is_em/I                                                *
// *Entries :  1451490 : Total  Size=    5807615 bytes  File Size  =      27991 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression= 207.46     *
// *............................................................................*
// *Br    4 :ll_m      : ll_m/F                                                 *
// *Entries :  1451490 : Total  Size=    5807596 bytes  File Size  =    5099889 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br    5 :bb_m      : bb_m/F                                                 *
// *Entries :  1451490 : Total  Size=    5807596 bytes  File Size  =    5188480 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br    6 :m_bl      : m_bl/F                                                 *
// *Entries :  1451490 : Total  Size=    5807596 bytes  File Size  =    5106193 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br    7 :yield     : yield/I                                                *
// *Entries :  1451490 : Total  Size=    5807615 bytes  File Size  =      29726 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression= 195.35     *
// *............................................................................*
// *Br    8 :bdt_1d    : bdt_1d/F                                               *
// *Entries :  1451490 : Total  Size=    5807634 bytes  File Size  =    5199944 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br    9 :event_number : event_number/l                                      *
// *Entries :  1451490 : Total  Size=   11614977 bytes  File Size  =    5328009 *
// *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.18     *
// *............................................................................*
// *Br   10 :vbf_0_eta : vbf_0_eta/F                                            *
// *Entries :  1451490 : Total  Size=    5807691 bytes  File Size  =    5376496 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   11 :vbf_1_eta : vbf_1_eta/F                                            *
// *Entries :  1451490 : Total  Size=    5807691 bytes  File Size  =    5365628 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   12 :vbf_jet_1_pt : vbf_jet_1_pt/F                                      *
// *Entries :  1451490 : Total  Size=    5807748 bytes  File Size  =    5123206 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   13 :vbf_dijets_DEta : vbf_dijets_DEta/F                                *
// *Entries :  1451490 : Total  Size=    5807805 bytes  File Size  =    5387921 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   14 :vbf_Dijets_Mass : vbf_Dijets_Mass/F                                *
// *Entries :  1451490 : Total  Size=    5807805 bytes  File Size  =    5189017 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   15 :vbf_bjet_0_eta : vbf_bjet_0_eta/F                                  *
// *Entries :  1451490 : Total  Size=    5807786 bytes  File Size  =    5385096 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   16 :vbf_m_bbll : vbf_m_bbll/F                                          *
// *Entries :  1451490 : Total  Size=    5807710 bytes  File Size  =    5062468 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   17 :vbf_deltar_min_bl : vbf_deltar_min_bl/F                            *
// *Entries :  1451490 : Total  Size=    5807843 bytes  File Size  =    5136356 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   18 :vbf_lept_0_eta : vbf_lept_0_eta/F                                  *
// *Entries :  1451490 : Total  Size=    5807786 bytes  File Size  =    5380331 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   19 :vbf_m_bbllmet : vbf_m_bbllmet/F                                    *
// *Entries :  1451490 : Total  Size=    5807767 bytes  File Size  =    5089441 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   20 :vbf_lept_1_eta : vbf_lept_1_eta/F                                  *
// *Entries :  1451490 : Total  Size=    5807786 bytes  File Size  =    5385334 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   21 :vbf_bb_deltar : vbf_bb_deltar/F                                    *
// *Entries :  1451490 : Total  Size=    5807767 bytes  File Size  =    5143824 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   22 :vbf_bjet_1_eta : vbf_bjet_1_eta/F                                  *
// *Entries :  1451490 : Total  Size=    5807786 bytes  File Size  =    5386742 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   23 :vbf_bb_pt : vbf_bb_pt/F                                            *
// *Entries :  1451490 : Total  Size=    5807691 bytes  File Size  =    5202509 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   24 :vbf_bjet_0_pt : vbf_bjet_0_pt/F                                    *
// *Entries :  1451490 : Total  Size=    5807767 bytes  File Size  =    5155691 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   25 :vbf_bjet_1_pt : vbf_bjet_1_pt/F                                    *
// *Entries :  1451490 : Total  Size=    5807767 bytes  File Size  =    5163708 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   26 :vbf_ll_deltaphi : vbf_ll_deltaphi/F                                *
// *Entries :  1451490 : Total  Size=    5807805 bytes  File Size  =    5370760 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   27 :vbf_m_ttbar : vbf_m_ttbar/F                                        *
// *Entries :  1451490 : Total  Size=    5807729 bytes  File Size  =    4958506 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.17     *
// *............................................................................*
// *Br   28 :vbf_0_phi : vbf_0_phi/F                                            *
// *Entries :  1451490 : Total  Size=    5807691 bytes  File Size  =    5380458 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   29 :vbf_bjet_0_phi : vbf_bjet_0_phi/F                                  *
// *Entries :  1451490 : Total  Size=    5807786 bytes  File Size  =    5381185 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   30 :vbf_sum_met_ptll : vbf_sum_met_ptll/F                              *
// *Entries :  1451490 : Total  Size=    5807824 bytes  File Size  =    5145072 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   31 :vbf_lept_1_phi : vbf_lept_1_phi/F                                  *
// *Entries :  1451490 : Total  Size=    5807786 bytes  File Size  =    5381930 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   32 :vbf_lept_1_pt : vbf_lept_1_pt/F                                    *
// *Entries :  1451490 : Total  Size=    5807767 bytes  File Size  =    5146634 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   33 :vbf_met_met : vbf_met_met/F                                        *
// *Entries :  1451490 : Total  Size=    5807729 bytes  File Size  =    5206312 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   34 :vbf_mcoll : vbf_mcoll/F                                            *
// *Entries :  1451490 : Total  Size=    5807691 bytes  File Size  =    5429159 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.07     *
// *............................................................................*
// *Br   35 :vbf_dphi_met_ll : vbf_dphi_met_ll/F                                *
// *Entries :  1451490 : Total  Size=    5807805 bytes  File Size  =    5377496 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   36 :vbf_bjet_1_phi : vbf_bjet_1_phi/F                                  *
// *Entries :  1451490 : Total  Size=    5807786 bytes  File Size  =    5381557 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   37 :vbf_ll_m  : vbf_ll_m/F                                             *
// *Entries :  1451490 : Total  Size=    5807672 bytes  File Size  =    5102353 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   38 :vbf_1_phi : vbf_1_phi/F                                            *
// *Entries :  1451490 : Total  Size=    5807691 bytes  File Size  =    5380696 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   39 :vbf_met_phi_centrality : vbf_met_phi_centrality/F                  *
// *Entries :  1451490 : Total  Size=    5807938 bytes  File Size  =    5372645 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   40 :vbf_bb_deltaphi : vbf_bb_deltaphi/F                                *
// *Entries :  1451490 : Total  Size=    5807805 bytes  File Size  =    5340699 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.09     *
// *............................................................................*
// *Br   41 :vbf_lept_0_pt : vbf_lept_0_pt/F                                    *
// *Entries :  1451490 : Total  Size=    5807767 bytes  File Size  =    5137458 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   42 :vbf_ll_pt : vbf_ll_pt/F                                            *
// *Entries :  1451490 : Total  Size=    5807691 bytes  File Size  =    5177077 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   43 :vbf_lept_0_phi : vbf_lept_0_phi/F                                  *
// *Entries :  1451490 : Total  Size=    5807786 bytes  File Size  =    5381840 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   44 :vbf_m_t2_bb : vbf_m_t2_bb/F                                        *
// *Entries :  1451490 : Total  Size=    5807729 bytes  File Size  =    5221665 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.11     *
// *............................................................................*
// *Br   45 :vbf_mmc_minu3p : vbf_mmc_minu3p/F                                  *
// *Entries :  1451490 : Total  Size=    5807786 bytes  File Size  =    3102828 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.87     *
// *............................................................................*
// *Br   46 :vbf_pt_bbllmet_vector : vbf_pt_bbllmet_vector/F                    *
// *Entries :  1451490 : Total  Size=    5807919 bytes  File Size  =    5089560 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   47 :vbf_pt_bbll_vector : vbf_pt_bbll_vector/F                          *
// *Entries :  1451490 : Total  Size=    5807862 bytes  File Size  =    5062589 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   48 :bdt_cvv0  : bdt_cvv0/F                                             *
// *Entries :  1451490 : Total  Size=    5807672 bytes  File Size  =    5205399 *
// *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   49 :weight    : weight/D                                               *
// *Entries :  1451490 : Total  Size=   11614785 bytes  File Size  =   10980762 *
// *Baskets :       28 : Basket Size=      32000 bytes  Compression=   1.06     *
// *............................................................................*
//  w bkg:   weight/41414.978893
//  w sig:   weight/0.220228
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %% [markdown]
// ## Declare DataLoader(s)
//
// The next step is to declare the DataLoader class that deals with input variables
//
// Define the input variables that shall be used for the MVA training
// note that you may also use variable expressions, which can be parsed by TTree::Draw( "expression" )]

// %%
TMVA::DataLoader * loader = new TMVA::DataLoader("dataset");

loader->AddVariable("vbf_0_eta");
loader->AddVariable("vbf_1_eta");
loader->AddVariable("vbf_jet_1_pt");
loader->AddVariable("vbf_dijets_DEta");
loader->AddVariable("vbf_Dijets_Mass");
loader->AddVariable("vbf_bjet_0_eta");
loader->AddVariable("vbf_m_bbll");
loader->AddVariable("vbf_deltar_min_bl");

loader->AddVariable("vbf_lept_0_eta");
loader->AddVariable("vbf_m_bbllmet");
loader->AddVariable("vbf_lept_1_eta");
loader->AddVariable("vbf_bb_deltar");
loader->AddVariable("vbf_bjet_1_eta");
loader->AddVariable("vbf_bb_pt");

loader->AddVariable("vbf_bjet_0_pt");
loader->AddVariable("vbf_bjet_1_pt");
loader->AddVariable("vbf_ll_deltaphi");
loader->AddVariable("vbf_m_ttbar");
loader->AddVariable("vbf_0_phi");
loader->AddVariable("vbf_bjet_0_phi");
loader->AddVariable("vbf_sum_met_ptll");
loader->AddVariable("vbf_lept_1_phi");
loader->AddVariable("vbf_lept_1_pt");
loader->AddVariable("vbf_met_met");
loader->AddVariable("vbf_mcoll");
loader->AddVariable("vbf_dphi_met_ll");
loader->AddVariable("vbf_bjet_1_phi");
loader->AddVariable("vbf_ll_m");
loader->AddVariable("vbf_1_phi");
loader->AddVariable("vbf_met_phi_centrality");
loader->AddVariable("vbf_bb_deltaphi");
loader->AddVariable("vbf_lept_0_pt");


loader->AddVariable("vbf_ll_pt");
loader->AddVariable("vbf_lept_0_phi");

loader->AddVariable("vbf_m_t2_bb");
loader->AddVariable("vbf_mmc_minu3p");

loader->AddVariable("vbf_pt_bbllmet_vector");
loader->AddVariable("vbf_pt_bbll_vector");


loader->AddSpectator("event_number", "event_number", "" );


cout<<"ok  "<<endl;
// Out:
// ok

// %% [markdown]
// We set now the input data trees in the TMVA DataLoader class

// %%
// global event weights (see below for setting event-wise weights)
Double_t weight2 = 1.0;
//TCut cutstr = "fmod(eventNumber, 2) == 0.";
//TCut cutste = "fmod(eventNumber, 2) == 1.";

//TCut cutstr = "BJet0Eta>0";
//TCut cutste = "BJet0Eta<0";

TCut cutstr = "";
TCut cutste = "";

//TCut cutstr = "(eventNumber%2)==0";
//TCut cutste = "(eventNumber%2)==1";

loader->AddTree (signalTreeTrain,        TString("Signal"), weight2, cutstr, TMVA::Types::kTraining);
loader->AddTree (signalTreeTest,          TString("Signal"), weight2, cutste, TMVA::Types::kTesting);
loader->AddTree (backgroundTreeTrain,TString("Background"), weight2, cutstr, TMVA::Types::kTraining);
loader->AddTree (backgroundTreeTest,  TString("Background"), weight2, cutste, TMVA::Types::kTesting);

cout<<"ok  "<<endl;

// set weights for individual events
loader->SetSignalWeightExpression(weight_sig);
loader->SetBackgroundWeightExpression(weight_bkg);

//loader_prepare_flags = ["nTrain_Signal=0", "nTrain_Background=0", "NormMode=None", "!V"];
//options = ":".join(loader_prepare_flags);
//loader->PrepareTrainingAndTestTree(TCut(""), TCut(""), options) ;

//loader->PrepareTrainingAndTestTree( mycuts, mycutb, "nTrain_Signal=10210:nTrain_Background=95503:SplitMode=Alternate:NormMode=NumEvents:!V" );
// Out:
// DataSetInfo              : [dataset] : Added class "Signal"
//                          : Add Tree test of type Signal with 8990 events
//                          : Add Tree test of type Signal with 27314 events
// DataSetInfo              : [dataset] : Added class "Background"
//                          : Add Tree test of type Background with 484305 events
//                          : Add Tree test of type Background with 1451490 events
// ok

// %% [markdown]
// # Booking Methods
//
// Here we book the TMVA methods. We book a Likelihood based on KDE, a Fischer discriminant and a BDT

// %%
// Likelihood ("naive Bayes estimator")
//factory.BookMethod(loader, TMVA::Types::kLikelihood, "Likelihood",
//                           "H:!V:TransformOutput:PDFInterpol=Spline2:NSmoothSig[0]=20:NSmoothBkg[0]=20:NSmoothBkg[1]=10:NSmooth=1:NAvEvtPerBin=50" );

// Use a kernel density estimator to approximate the PDFs
//factory.BookMethod(loader, TMVA::Types::kLikelihood, "LikelihoodKDE",
//                           "!H:!V:!TransformOutput:PDFInterpol=KDE:KDEtype=Gauss:KDEiter=Adaptive:KDEFineFactor=0.3:KDEborder=None:NAvEvtPerBin=50" ); 


// Fisher discriminant (same as LD)
//factory.BookMethod(loader, TMVA::Types::kFisher, "Fisher", "H:!V:Fisher:VarTransform=None:CreateMVAPdfs:PDFInterpolMVAPdf=Spline2:NbinsMVAPdf=50:NsmoothMVAPdf=10" );


//Boosted Decision Trees
factory.BookMethod(loader,TMVA::Types::kBDT, "BDT",
                   "!V:NTrees=350:MinNodeSize=2.5%:MaxDepth=3:BoostType=AdaBoost:AdaBoostBeta=0.5:UseBaggedBoost:BaggedSampleFraction=0.5:SeparationType=GiniIndex:nCuts=20" );

//Multi-Layer Perceptron (Neural Network)
//factory.BookMethod(loader, TMVA::Types::kMLP, "MLP",
//                   "!H:!V:NeuronType=tanh:VarTransform=N:NCycles=100:HiddenLayers=N+5:TestRate=5:!UseRegulator" );
// Out:
// Factory                  : Booking method: BDT
//                          :
//                          : Building event vectors for type 0 Signal
//                          : Dataset[dataset] :  create input formulas for tree test
//                          : Building event vectors for type 1 Signal
//                          : Dataset[dataset] :  create input formulas for tree test
//                          : Building event vectors for type 0 Background
//                          : Dataset[dataset] :  create input formulas for tree test
//                          : Building event vectors for type 1 Background
//                          : Dataset[dataset] :  create input formulas for tree test
// DataSetFactory           : [dataset] : Number of events in input trees
//                          :
//                          :
//                          : Dataset[dataset] : Weight renormalisation mode: "EqualNumEvents": renormalises all event classes ...
//                          : Dataset[dataset] :  such that the effective (weighted) number of events in each class is the same
//                          : Dataset[dataset] :  (and equals the number of events (entries) given for class=0 )
//                          : Dataset[dataset] : ... i.e. such that Sum[i=1..N_j]{w_i} = N_classA, j=classA, classB, ...
//                          : Dataset[dataset] : ... (note that N_j is the sum of TRAINING events
//                          : Dataset[dataset] :  ..... Testing events are not renormalised nor included in the renormalisation factor!)
//                          : Number of training and testing events
//                          : ---------------------------------------------------------------------------
//                          : Signal     -- training events            : 8990
//                          : Signal     -- testing events             : 27314
//                          : Signal     -- training and testing events: 36304
//                          : Background -- training events            : 484305
//                          : Background -- testing events             : 1451490
//                          : Background -- training and testing events: 1935795
//                          :
// DataSetInfo              : Correlation matrix (Signal):
//                          : --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//                          :                         vbf_0_eta vbf_1_eta vbf_jet_1_pt vbf_dijets_DEta vbf_Dijets_Mass vbf_bjet_0_eta vbf_m_bbll vbf_deltar_min_bl vbf_lept_0_eta vbf_m_bbllmet vbf_lept_1_eta vbf_bb_deltar vbf_bjet_1_eta vbf_bb_pt vbf_bjet_0_pt vbf_bjet_1_pt vbf_ll_deltaphi vbf_m_ttbar vbf_0_phi vbf_bjet_0_phi vbf_sum_met_ptll vbf_lept_1_phi vbf_lept_1_pt vbf_met_met vbf_mcoll vbf_dphi_met_ll vbf_bjet_1_phi vbf_ll_m vbf_1_phi vbf_met_phi_centrality vbf_bb_deltaphi vbf_lept_0_pt vbf_ll_pt vbf_lept_0_phi vbf_m_t2_bb vbf_mmc_minu3p vbf_pt_bbllmet_vector vbf_pt_bbll_vector
//                          :              vbf_0_eta:    +1.000    -0.753       -0.002          +0.007          +0.001         -0.004     -0.006            -0.016         +0.005        -0.008         +0.012        +0.012         -0.009    -0.003        +0.003        -0.012          -0.003      -0.002    +0.002         -0.020           -0.008         -0.006        +0.009      -0.004    +0.004          -0.001         +0.022   +0.020    +0.015                 +0.007          +0.008        -0.014    -0.007         +0.014      -0.006         +0.019                -0.008             -0.006
//                          :              vbf_1_eta:    -0.753    +1.000       +0.002          -0.014          -0.004         +0.087     +0.000            +0.014         +0.073        +0.000         +0.067        -0.009         +0.095    -0.003        -0.009        +0.012          +0.006      +0.006    +0.007         +0.005           +0.002         +0.012        -0.015      +0.001    -0.001          -0.007         -0.016   -0.019    -0.001                 -0.001          +0.007        +0.005    -0.002         -0.014      +0.000         -0.018                +0.000             +0.000
//                          :           vbf_jet_1_pt:    -0.002    +0.002       +1.000          -0.006          +0.016         -0.021     +0.069            -0.085         +0.005        +0.111         +0.013        -0.199         -0.015    +0.240        +0.209        +0.150          +0.005      +0.001    -0.023         -0.007           +0.108         +0.009        +0.150      +0.202    -0.003          -0.012         -0.000   -0.007    +0.013                 +0.084          +0.009        +0.186    +0.204         +0.016      +0.089         -0.000                +0.111             +0.069
//                          :        vbf_dijets_DEta:    +0.007    -0.014       -0.006          +1.000          -0.071         +0.361     -0.019            -0.005         -0.032        -0.025         -0.033        -0.016         -0.427    -0.001        -0.004        -0.001          -0.004      +0.009    +0.007         +0.008           -0.020         -0.001        -0.013      -0.022    -0.002          -0.007         -0.003   +0.013    +0.007                 -0.003          -0.010        -0.005    -0.012         +0.001      -0.014         +0.030                -0.025             -0.019
//                          :        vbf_Dijets_Mass:    +0.001    -0.004       +0.016          -0.071          +1.000         -0.019     +0.258            -0.017         +0.018        +0.266         +0.016        +0.224         +0.037    +0.171        +0.259        +0.277          -0.005      +0.025    -0.005         +0.006           -0.015         +0.005        +0.029      +0.082    +0.009          +0.001         +0.001   -0.004    +0.007                 +0.031          -0.013        +0.030    +0.035         +0.005      +0.137         -0.001                +0.266             +0.258
//                          :         vbf_bjet_0_eta:    -0.004    +0.087       -0.021          +0.361          -0.019         +1.000     -0.031            -0.006         -0.242        -0.040         -0.225        +0.013         +0.690    -0.011        -0.003        -0.012          +0.015      +0.006    +0.016         -0.011           -0.015         +0.002        -0.005      -0.022    +0.000          +0.005         -0.000   +0.024    -0.005                 -0.018          -0.002        -0.000    -0.006         -0.003      -0.021         +0.028                -0.040             -0.031
//                          :             vbf_m_bbll:    -0.006    +0.000       +0.069          -0.019          +0.258         -0.031     +1.000            +0.671         +0.030        +0.915         +0.028        -0.299         -0.015    +0.463        +0.449        +0.334          +0.002      +0.005    -0.012         +0.040           +0.392         +0.004        +0.358      +0.127    -0.014          +0.014         -0.020   +0.063    +0.002                 +0.060          -0.007        +0.480    +0.501         +0.024      +0.323         -0.018                +0.915             +1.000
//                          :      vbf_deltar_min_bl:    -0.016    +0.014       -0.085          -0.005          -0.017         -0.006     +0.671            +1.000         +0.011        +0.614         +0.007        -0.275         -0.002    +0.218        +0.151        +0.177          +0.006      +0.132    +0.003         +0.030           +0.255         -0.005        +0.171      +0.091    -0.021          +0.001         -0.005   -0.129    -0.017                 +0.021          -0.007        +0.160    +0.213         +0.005      +0.272         -0.112                +0.614             +0.671
//                          :         vbf_lept_0_eta:    +0.005    +0.073       +0.005          -0.032          +0.018         -0.242     +0.030            +0.011         +1.000        +0.021         +0.821        +0.008         -0.209    -0.005        -0.013        +0.017          -0.006      -0.001    -0.002         +0.014           +0.004         +0.009        +0.016      +0.001    -0.006          -0.005         -0.020   +0.005    +0.006                 +0.007          +0.002        +0.001    +0.007         +0.004      -0.008         -0.013                +0.021             +0.030
//                          :          vbf_m_bbllmet:    -0.008    +0.000       +0.111          -0.025          +0.266         -0.040     +0.915            +0.614         +0.021        +1.000         +0.015        -0.393         -0.020    +0.599        +0.582        +0.408          +0.004      +0.035    -0.024         +0.035           +0.485         +0.002        +0.321      +0.464    -0.011          +0.011         -0.015   -0.005    +0.003                 +0.138          -0.007        +0.433    +0.464         +0.019      +0.586         -0.077                +1.000             +0.915
//                          :         vbf_lept_1_eta:    +0.012    +0.067       +0.013          -0.033          +0.016         -0.225     +0.028            +0.007         +0.821        +0.015         +1.000        +0.006         -0.192    -0.007        -0.016        +0.011          -0.009      +0.002    +0.008         +0.006           +0.000         +0.007        +0.021      -0.007    +0.001          -0.009         -0.009   -0.003    +0.009                 +0.001          +0.003        +0.004    +0.013         -0.001      -0.014         -0.015                +0.015             +0.028
//                          :          vbf_bb_deltar:    +0.012    -0.009       -0.199          -0.016          +0.224         +0.013     -0.299            -0.275         +0.008        -0.393         +0.006        +1.000         +0.025    -0.757        -0.536        -0.541          -0.002      -0.132    +0.022         -0.015           -0.134         -0.013        -0.139      -0.259    +0.016          +0.003         +0.020   +0.019    +0.005                 -0.138          +0.003        -0.223    -0.234         -0.011      -0.592         -0.007                -0.393             -0.299
//                          :         vbf_bjet_1_eta:    -0.009    +0.095       -0.015          -0.427          +0.037         +0.690     -0.015            -0.002         -0.209        -0.020         -0.192        +0.025         +1.000    -0.010        -0.000        -0.011          +0.018      -0.001    +0.010         -0.017           +0.001         +0.003        +0.006      -0.005    +0.001          +0.011         +0.002   +0.013    -0.011                 -0.015          +0.006        +0.004    +0.003         -0.003      -0.010         +0.003                -0.020             -0.015
//                          :              vbf_bb_pt:    -0.003    -0.003       +0.240          -0.001          +0.171         -0.011     +0.463            +0.218         -0.005        +0.599         -0.007        -0.757         -0.010    +1.000        +0.916        +0.603          +0.005      +0.080    -0.029         +0.013           +0.173         +0.008        +0.183      +0.386    -0.007          +0.018         -0.011   -0.018    +0.002                 +0.164          -0.010        +0.297    +0.307         +0.008      +0.686         +0.001                +0.599             +0.463
//                          :          vbf_bjet_0_pt:    +0.003    -0.009       +0.209          -0.004          +0.259         -0.003     +0.449            +0.151         -0.013        +0.582         -0.016        -0.536         -0.000    +0.916        +1.000        +0.377          +0.006      +0.027    -0.025         +0.014           +0.161         +0.001        +0.170      +0.371    -0.004          +0.025         -0.004   -0.014    +0.006                 +0.146          -0.011        +0.275    +0.285         +0.003      +0.548         +0.002                +0.582             +0.449
//                          :          vbf_bjet_1_pt:    -0.012    +0.012       +0.150          -0.001          +0.277         -0.012     +0.334            +0.177         +0.017        +0.408         +0.011        -0.541         -0.011    +0.603        +0.377        +1.000          +0.001      +0.201    -0.013         +0.003           +0.086         +0.018        +0.117      +0.232    +0.001          -0.006         -0.017   -0.014    -0.012                 +0.101          -0.003        +0.177    +0.186         +0.014      +0.567         -0.003                +0.408             +0.334
//                          :        vbf_ll_deltaphi:    -0.003    +0.006       +0.005          -0.004          -0.005         +0.015     +0.002            +0.006         -0.006        +0.004         -0.009        -0.002         +0.018    +0.005        +0.006        +0.001          +1.000      -0.002    +0.007         -0.008           +0.000         -0.015        +0.016      +0.006    -0.000          -0.034         -0.012   -0.003    -0.003                 +0.028          -0.018        -0.002    +0.006         -0.003      -0.002         +0.000                +0.004             +0.002
//                          :            vbf_m_ttbar:    -0.002    +0.006       +0.001          +0.009          +0.025         +0.006     +0.005            +0.132         -0.001        +0.035         +0.002        -0.132         -0.001    +0.080        +0.027        +0.201          -0.002      +1.000    -0.005         +0.003           -0.097         +0.008        -0.091      +0.081    +0.013          +0.010         -0.006   +0.026    +0.007                 +0.066          +0.007        -0.044    -0.072         -0.021      +0.157         +0.055                +0.035             +0.005
//                          :              vbf_0_phi:    +0.002    +0.007       -0.023          +0.007          -0.005         +0.016     -0.012            +0.003         -0.002        -0.024         +0.008        +0.022         +0.010    -0.029        -0.025        -0.013          +0.007      -0.005    +1.000         -0.142           -0.004         -0.160        -0.021      -0.025    -0.003          +0.005         -0.084   -0.010    +0.054                 -0.005          +0.016        -0.009    -0.012         -0.203      -0.023         -0.005                -0.024             -0.012
//                          :         vbf_bjet_0_phi:    -0.020    +0.005       -0.007          +0.008          +0.006         -0.011     +0.040            +0.030         +0.014        +0.035         +0.006        -0.015         -0.017    +0.013        +0.014        +0.003          -0.008      +0.003    -0.142         +1.000           +0.007         -0.138        +0.013      -0.004    +0.000          -0.005         -0.038   -0.004    -0.121                 -0.010          -0.019        +0.004    +0.009         -0.203      +0.008         -0.011                +0.035             +0.040
//                          :       vbf_sum_met_ptll:    -0.008    +0.002       +0.108          -0.020          -0.015         -0.015     +0.392            +0.255         +0.004        +0.485         +0.000        -0.134         +0.001    +0.173        +0.161        +0.086          +0.000      -0.097    -0.004         +0.007           +1.000         -0.004        +0.216      +0.373    -0.019          -0.006         +0.002   +0.068    -0.012                 -0.074          +0.012        +0.239    +0.254         +0.012      +0.240         -0.148                +0.485             +0.392
//                          :         vbf_lept_1_phi:    -0.006    +0.012       +0.009          -0.001          +0.005         +0.002     +0.004            -0.005         +0.009        +0.002         +0.007        -0.013         +0.003    +0.008        +0.001        +0.018          -0.015      +0.008    -0.160         -0.138           -0.004         +1.000        -0.002      -0.007    -0.006          -0.014         -0.109   +0.004    -0.096                 +0.004          -0.011        +0.009    +0.006         +0.258      +0.007         -0.003                +0.002             +0.004
//                          :          vbf_lept_1_pt:    +0.009    -0.015       +0.150          -0.013          +0.029         -0.005     +0.358            +0.171         +0.016        +0.321         +0.021        -0.139         +0.006    +0.183        +0.170        +0.117          +0.016      -0.091    -0.021         +0.013           +0.216         -0.002        +1.000      +0.059    -0.008          +0.012         +0.016   +0.055    +0.015                 +0.008          +0.002        +0.427    +0.685         -0.009      +0.107         -0.071                +0.321             +0.358
//                          :            vbf_met_met:    -0.004    +0.001       +0.202          -0.022          +0.082         -0.022     +0.127            +0.091         +0.001        +0.464         -0.007        -0.259         -0.005    +0.386        +0.371        +0.232          +0.006      +0.081    -0.025         -0.004           +0.373         -0.007        +0.059      +1.000    -0.002          -0.001         +0.012   -0.131    -0.004                 +0.269          -0.002        +0.070    +0.105         -0.000      +0.684         -0.130                +0.464             +0.127
//                          :              vbf_mcoll:    +0.004    -0.001       -0.003          -0.002          +0.009         +0.000     -0.014            -0.021         -0.006        -0.011         +0.001        +0.016         +0.001    -0.007        -0.004        +0.001          -0.000      +0.013    -0.003         +0.000           -0.019         -0.006        -0.008      -0.002    +1.000          +0.001         -0.006   +0.029    +0.001                 +0.025          +0.004        -0.004    -0.023         +0.004      +0.002         +0.047                -0.011             -0.014
//                          :        vbf_dphi_met_ll:    -0.001    -0.007       -0.012          -0.007          +0.001         +0.005     +0.014            +0.001         -0.005        +0.011         -0.009        +0.003         +0.011    +0.018        +0.025        -0.006          -0.034      +0.010    +0.005         -0.005           -0.006         -0.014        +0.012      -0.001    +0.001          +1.000         +0.003   +0.013    +0.008                 +0.016          +0.004        +0.017    +0.015         -0.015      -0.002         +0.023                +0.011             +0.014
//                          :         vbf_bjet_1_phi:    +0.022    -0.016       -0.000          -0.003          +0.001         -0.000     -0.020            -0.005         -0.020        -0.015         -0.009        +0.020         +0.002    -0.011        -0.004        -0.017          -0.012      -0.006    -0.084         -0.038           +0.002         -0.109        +0.016      +0.012    -0.006          +0.003         +1.000   +0.004    -0.046                 -0.019          +0.016        +0.003    +0.006         -0.130      -0.006         -0.001                -0.015             -0.020
//                          :               vbf_ll_m:    +0.020    -0.019       -0.007          +0.013          -0.004         +0.024     +0.063            -0.129         +0.005        -0.005         -0.003        +0.019         +0.013    -0.018        -0.014        -0.014          -0.003      +0.026    -0.010         -0.004           +0.068         +0.004        +0.055      -0.131    +0.029          +0.013         +0.004   +1.000    +0.009                 +0.179          -0.003        +0.097    -0.047         +0.011      -0.072         +0.679                -0.005             +0.063
//                          :              vbf_1_phi:    +0.015    -0.001       +0.013          +0.007          +0.007         -0.005     +0.002            -0.017         +0.006        +0.003         +0.009        +0.005         -0.011    +0.002        +0.006        -0.012          -0.003      +0.007    +0.054         -0.121           -0.012         -0.096        +0.015      -0.004    +0.001          +0.008         -0.046   +0.009    +1.000                 +0.001          +0.005        -0.008    -0.000         -0.088      -0.002         +0.007                +0.003             +0.002
//                          : vbf_met_phi_centrality:    +0.007    -0.001       +0.084          -0.003          +0.031         -0.018     +0.060            +0.021         +0.007        +0.138         +0.001        -0.138         -0.015    +0.164        +0.146        +0.101          +0.028      +0.066    -0.005         -0.010           -0.074         +0.004        +0.008      +0.269    +0.025          +0.016         -0.019   +0.179    +0.001                 +1.000          -0.002        +0.051    +0.022         -0.004      +0.275         +0.435                +0.138             +0.060
//                          :        vbf_bb_deltaphi:    +0.008    +0.007       +0.009          -0.010          -0.013         -0.002     -0.007            -0.007         +0.002        -0.007         +0.003        +0.003         +0.006    -0.010        -0.011        -0.003          -0.018      +0.007    +0.016         -0.019           +0.012         -0.011        +0.002      -0.002    +0.004          +0.004         +0.016   -0.003    +0.005                 -0.002          +1.000        +0.013    +0.012         +0.000      -0.009         -0.008                -0.007             -0.007
//                          :          vbf_lept_0_pt:    -0.014    +0.005       +0.186          -0.005          +0.030         -0.000     +0.480            +0.160         +0.001        +0.433         +0.004        -0.223         +0.004    +0.297        +0.275        +0.177          -0.002      -0.044    -0.009         +0.004           +0.239         +0.009        +0.427      +0.070    -0.004          +0.017         +0.003   +0.097    -0.008                 +0.051          +0.013        +1.000    +0.925         +0.014      +0.168         -0.032                +0.433             +0.480
//                          :              vbf_ll_pt:    -0.007    -0.002       +0.204          -0.012          +0.035         -0.006     +0.501            +0.213         +0.007        +0.464         +0.013        -0.234         +0.003    +0.307        +0.285        +0.186          +0.006      -0.072    -0.012         +0.009           +0.254         +0.006        +0.685      +0.105    -0.023          +0.015         +0.006   -0.047    -0.000                 +0.022          +0.012        +0.925    +1.000         +0.005      +0.191         -0.158                +0.464             +0.501
//                          :         vbf_lept_0_phi:    +0.014    -0.014       +0.016          +0.001          +0.005         -0.003     +0.024            +0.005         +0.004        +0.019         -0.001        -0.011         -0.003    +0.008        +0.003        +0.014          -0.003      -0.021    -0.203         -0.203           +0.012         +0.258        -0.009      -0.000    +0.004          -0.015         -0.130   +0.011    -0.088                 -0.004          +0.000        +0.014    +0.005         +1.000      +0.007         +0.011                +0.019             +0.024
//                          :            vbf_m_t2_bb:    -0.006    +0.000       +0.089          -0.014          +0.137         -0.021     +0.323            +0.272         -0.008        +0.586         -0.014        -0.592         -0.010    +0.686        +0.548        +0.567          -0.002      +0.157    -0.023         +0.008           +0.240         +0.007        +0.107      +0.684    +0.002          -0.002         -0.006   -0.072    -0.002                 +0.275          -0.009        +0.168    +0.191         +0.007      +1.000         -0.023                +0.586             +0.323
//                          :         vbf_mmc_minu3p:    +0.019    -0.018       -0.000          +0.030          -0.001         +0.028     -0.018            -0.112         -0.013        -0.077         -0.015        -0.007         +0.003    +0.001        +0.002        -0.003          +0.000      +0.055    -0.005         -0.011           -0.148         -0.003        -0.071      -0.130    +0.047          +0.023         -0.001   +0.679    +0.007                 +0.435          -0.008        -0.032    -0.158         +0.011      -0.023         +1.000                -0.077             -0.018
//                          :  vbf_pt_bbllmet_vector:    -0.008    +0.000       +0.111          -0.025          +0.266         -0.040     +0.915            +0.614         +0.021        +1.000         +0.015        -0.393         -0.020    +0.599        +0.582        +0.408          +0.004      +0.035    -0.024         +0.035           +0.485         +0.002        +0.321      +0.464    -0.011          +0.011         -0.015   -0.005    +0.003                 +0.138          -0.007        +0.433    +0.464         +0.019      +0.586         -0.077                +1.000             +0.915
//                          :     vbf_pt_bbll_vector:    -0.006    +0.000       +0.069          -0.019          +0.258         -0.031     +1.000            +0.671         +0.030        +0.915         +0.028        -0.299         -0.015    +0.463        +0.449        +0.334          +0.002      +0.005    -0.012         +0.040           +0.392         +0.004        +0.358      +0.127    -0.014          +0.014         -0.020   +0.063    +0.002                 +0.060          -0.007        +0.480    +0.501         +0.024      +0.323         -0.018                +0.915             +1.000
//                          : --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// DataSetInfo              : Correlation matrix (Background):
//                          : --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//                          :                         vbf_0_eta vbf_1_eta vbf_jet_1_pt vbf_dijets_DEta vbf_Dijets_Mass vbf_bjet_0_eta vbf_m_bbll vbf_deltar_min_bl vbf_lept_0_eta vbf_m_bbllmet vbf_lept_1_eta vbf_bb_deltar vbf_bjet_1_eta vbf_bb_pt vbf_bjet_0_pt vbf_bjet_1_pt vbf_ll_deltaphi vbf_m_ttbar vbf_0_phi vbf_bjet_0_phi vbf_sum_met_ptll vbf_lept_1_phi vbf_lept_1_pt vbf_met_met vbf_mcoll vbf_dphi_met_ll vbf_bjet_1_phi vbf_ll_m vbf_1_phi vbf_met_phi_centrality vbf_bb_deltaphi vbf_lept_0_pt vbf_ll_pt vbf_lept_0_phi vbf_m_t2_bb vbf_mmc_minu3p vbf_pt_bbllmet_vector vbf_pt_bbll_vector
//                          :              vbf_0_eta:    +1.000    -0.261       +0.000          +0.010          +0.003         +0.061     +0.003            +0.002         +0.060        +0.000         +0.053        +0.006         +0.045    +0.001        -0.002        -0.003          +0.004      +0.001    -0.006         -0.000           -0.003         +0.008        +0.002      -0.002    -0.002          -0.004         +0.002   +0.002    +0.001                 +0.001          +0.002        -0.002    +0.000         -0.002      +0.001         -0.002                +0.000             +0.003
//                          :              vbf_1_eta:    -0.261    +1.000       -0.000          +0.004          -0.003         +0.033     -0.002            -0.002         +0.035        -0.001         +0.030        -0.000         +0.026    -0.003        -0.000        +0.001          -0.003      -0.002    +0.005         -0.001           +0.001         -0.003        +0.000      +0.002    +0.002          +0.003         -0.004   +0.004    -0.003                 +0.008          +0.004        -0.002    -0.006         -0.001      -0.001         +0.005                -0.001             -0.002
//                          :           vbf_jet_1_pt:    +0.000    -0.000       +1.000          +0.002          +0.045         +0.002     +0.056            -0.116         +0.002        +0.090         +0.005        -0.086         -0.000    +0.266        +0.201        +0.071          +0.003      -0.005    -0.002         -0.002           +0.064         +0.000        +0.074      +0.240    -0.002          -0.000         -0.002   +0.001    +0.003                 +0.113          -0.000        +0.146    +0.155         +0.001      -0.028         +0.013                +0.090             +0.056
//                          :        vbf_dijets_DEta:    +0.010    +0.004       +0.002          +1.000          -0.000         +0.576     +0.000            -0.003         +0.052        -0.001         +0.062        +0.001         -0.653    -0.000        +0.000        +0.002          -0.001      +0.000    +0.003         +0.000           -0.004         -0.006        -0.001      +0.000    -0.002          +0.003         -0.000   -0.004    +0.003                 +0.003          +0.001        +0.001    +0.001         +0.005      -0.003         +0.003                -0.001             +0.000
//                          :        vbf_Dijets_Mass:    +0.003    -0.003       +0.045          -0.000          +1.000         +0.002     +0.849            -0.189         -0.005        +0.735         -0.002        +0.631         +0.002    +0.161        +0.608        +0.670          +0.005      +0.093    -0.004         +0.002           +0.031         +0.001        -0.055      +0.030    +0.002          -0.004         -0.000   +0.054    +0.001                 -0.048          -0.000        +0.001    -0.034         -0.003      -0.041         +0.009                +0.735             +0.849
//                          :         vbf_bjet_0_eta:    +0.061    +0.033       +0.002          +0.576          +0.002         +1.000     -0.001            -0.008         +0.490        -0.002         +0.442        +0.000         +0.242    +0.003        +0.004        +0.002          -0.000      -0.002    -0.000         -0.002           -0.004         -0.001        -0.002      +0.000    -0.002          +0.001         +0.001   -0.004    +0.002                 -0.002          +0.001        +0.001    +0.002         +0.007      -0.001         +0.002                -0.002             -0.001
//                          :             vbf_m_bbll:    +0.003    -0.002       +0.056          +0.000          +0.849         -0.001     +1.000            +0.048         -0.002        +0.843         -0.000        +0.425         -0.001    +0.282        +0.602        +0.563          +0.002      +0.017    -0.003         +0.000           +0.138         +0.000        +0.087      -0.005    +0.001          -0.001         +0.000   +0.194    -0.001                 -0.003          -0.003        +0.266    +0.219         -0.001      +0.012         +0.067                +0.843             +1.000
//                          :      vbf_deltar_min_bl:    +0.002    -0.002       -0.116          -0.003          -0.189         -0.008     +0.048            +1.000         +0.005        -0.048         +0.005        -0.168         -0.004    -0.026        -0.234        -0.237          -0.002      -0.003    -0.003         -0.004           -0.100         +0.006        +0.033      -0.130    -0.004          +0.001         -0.000   -0.131    +0.002                 +0.075          -0.001        -0.010    +0.090         -0.001      +0.013         -0.010                -0.048             +0.048
//                          :         vbf_lept_0_eta:    +0.060    +0.035       +0.002          +0.052          -0.005         +0.490     -0.002            +0.005         +1.000        -0.004         +0.522        -0.003         +0.393    -0.002        -0.004        -0.002          -0.002      +0.000    +0.003         -0.002           -0.004         -0.005        -0.000      -0.003    +0.002          -0.003         -0.005   -0.002    -0.006                 +0.007          +0.001        +0.001    -0.002         +0.001      -0.002         +0.003                -0.004             -0.002
//                          :          vbf_m_bbllmet:    +0.000    -0.001       +0.090          -0.001          +0.735         -0.002     +0.843            -0.048         -0.004        +1.000         -0.004        +0.310         -0.001    +0.346        +0.609        +0.501          +0.003      +0.011    -0.002         +0.001           +0.498         +0.000        +0.034      +0.406    +0.002          -0.001         -0.000   +0.161    -0.001                 -0.035          -0.003        +0.237    +0.177         -0.001      +0.297         -0.139                +1.000             +0.843
//                          :         vbf_lept_1_eta:    +0.053    +0.030       +0.005          +0.062          -0.002         +0.442     -0.000            +0.005         +0.522        -0.004         +1.000        -0.002         +0.336    -0.002        -0.003        -0.001          -0.005      +0.001    +0.001         -0.003           -0.003         -0.001        -0.000      -0.001    -0.002          -0.001         -0.001   +0.002    -0.003                 +0.006          +0.001        -0.000    -0.001         +0.001      -0.003         +0.002                -0.004             -0.000
//                          :          vbf_bb_deltar:    +0.006    -0.000       -0.086          +0.001          +0.631         +0.000     +0.425            -0.168         -0.003        +0.310         -0.002        +1.000         -0.001    -0.440        +0.081        +0.133          +0.003      +0.014    -0.003         +0.002           +0.001         +0.002        -0.063      -0.043    +0.002          -0.004         +0.004   +0.039    +0.005                 -0.087          -0.001        -0.040    -0.066         +0.001      -0.373         -0.004                +0.310             +0.425
//                          :         vbf_bjet_1_eta:    +0.045    +0.026       -0.000          -0.653          +0.002         +0.242     -0.001            -0.004         +0.393        -0.001         +0.336        -0.001         +1.000    +0.003        +0.003        -0.000          +0.001      -0.002    -0.003         -0.002           +0.001         +0.006        -0.001      -0.000    +0.001          -0.002         +0.001   +0.001    -0.001                 -0.005          -0.001        -0.000    +0.000         +0.000      +0.002         -0.001                -0.001             -0.001
//                          :              vbf_bb_pt:    +0.001    -0.003       +0.266          -0.000          +0.161         +0.003     +0.282            -0.026         -0.002        +0.346         -0.002        -0.440         +0.003    +1.000        +0.712        +0.241          +0.004      +0.030    -0.002         -0.002           +0.047         +0.002        +0.035      +0.153    +0.000          +0.001         -0.004   +0.011    -0.001                 +0.078          -0.002        +0.090    +0.084         -0.003      +0.386         +0.011                +0.346             +0.282
//                          :          vbf_bjet_0_pt:    -0.002    -0.000       +0.201          +0.000          +0.608         +0.004     +0.602            -0.234         -0.004        +0.609         -0.003        +0.081         +0.003    +0.712        +1.000        +0.536          +0.004      +0.062    -0.001         +0.000           +0.069         -0.000        -0.005      +0.137    +0.002          -0.002         -0.004   +0.039    -0.001                 +0.015          -0.003        +0.085    +0.049         -0.002      +0.128         +0.008                +0.609             +0.602
//                          :          vbf_bjet_1_pt:    -0.003    +0.001       +0.071          +0.002          +0.670         +0.002     +0.563            -0.237         -0.002        +0.501         -0.001        +0.133         -0.000    +0.241        +0.536        +1.000          +0.004      +0.154    -0.002         +0.002           +0.019         +0.000        -0.024      +0.020    +0.001          -0.002         -0.001   +0.024    -0.001                 -0.040          +0.002        -0.002    -0.025         -0.002      +0.087         +0.009                +0.501             +0.563
//                          :        vbf_ll_deltaphi:    +0.004    -0.003       +0.003          -0.001          +0.005         -0.000     +0.002            -0.002         -0.002        +0.003         -0.005        +0.003         +0.001    +0.004        +0.004        +0.004          +1.000      +0.005    -0.005         -0.001           -0.001         -0.002        +0.000      +0.004    -0.003          +0.021         +0.007   -0.005    +0.008                 -0.004          -0.004        +0.001    +0.007         +0.004      +0.002         -0.012                +0.003             +0.002
//                          :            vbf_m_ttbar:    +0.001    -0.002       -0.005          +0.000          +0.093         -0.002     +0.017            -0.003         +0.000        +0.011         +0.001        +0.014         -0.002    +0.030        +0.062        +0.154          +0.005      +1.000    -0.007         -0.003           -0.101         +0.004        -0.082      +0.024    +0.002          -0.000         +0.002   -0.006    -0.003                 +0.023          +0.002        -0.089    -0.118         -0.000      +0.063         +0.023                +0.011             +0.017
//                          :              vbf_0_phi:    -0.006    +0.005       -0.002          +0.003          -0.004         -0.000     -0.003            -0.003         +0.003        -0.002         +0.001        -0.003         -0.003    -0.002        -0.001        -0.002          -0.005      -0.007    +1.000         -0.189           +0.001         -0.089        +0.002      +0.001    -0.000          -0.002         -0.040   +0.002    -0.035                 +0.002          -0.000        +0.001    +0.000         -0.143      -0.008         +0.003                -0.002             -0.003
//                          :         vbf_bjet_0_phi:    -0.000    -0.001       -0.002          +0.000          +0.002         -0.002     +0.000            -0.004         -0.002        +0.001         -0.003        +0.002         -0.002    -0.002        +0.000        +0.002          -0.001      -0.003    -0.189         +1.000           -0.001         -0.048        -0.003      +0.001    +0.001          -0.002         -0.101   -0.001    -0.077                 -0.006          -0.000        -0.001    -0.001         -0.070      +0.003         -0.002                +0.001             +0.000
//                          :       vbf_sum_met_ptll:    -0.003    +0.001       +0.064          -0.004          +0.031         -0.004     +0.138            -0.100         -0.004        +0.498         -0.003        +0.001         +0.001    +0.047        +0.069        +0.019          -0.001      -0.101    +0.001         -0.001           +1.000         +0.000        +0.102      +0.541    -0.000          -0.001         +0.002   +0.306    +0.001                 -0.247          -0.003        +0.311    +0.228         +0.004      +0.201         -0.324                +0.498             +0.138
//                          :         vbf_lept_1_phi:    +0.008    -0.003       +0.000          -0.006          +0.001         -0.001     +0.000            +0.006         -0.005        +0.000         -0.001        +0.002         +0.006    +0.002        -0.000        +0.000          -0.002      +0.004    -0.089         -0.048           +0.000         +1.000        -0.002      +0.001    +0.001          -0.004         -0.058   -0.006    -0.037                 -0.006          -0.003        -0.000    +0.002         +0.087      +0.003         -0.007                +0.000             +0.000
//                          :          vbf_lept_1_pt:    +0.002    +0.000       +0.074          -0.001          -0.055         -0.002     +0.087            +0.033         -0.000        +0.034         -0.000        -0.063         -0.001    +0.035        -0.005        -0.024          +0.000      -0.082    +0.002         -0.003           +0.102         -0.002        +1.000      -0.064    -0.004          -0.000         -0.003   +0.255    -0.001                 +0.059          +0.001        +0.196    +0.428         -0.002      -0.047         +0.096                +0.034             +0.087
//                          :            vbf_met_met:    -0.002    +0.002       +0.240          +0.000          +0.030         +0.000     -0.005            -0.130         -0.003        +0.406         -0.001        -0.043         -0.000    +0.153        +0.137        +0.020          +0.004      +0.024    +0.001         +0.001           +0.541         +0.001        -0.064      +1.000    +0.001          +0.001         -0.002   +0.004    +0.003                 +0.078          -0.001        +0.027    -0.006         -0.001      +0.376         -0.320                +0.406             -0.005
//                          :              vbf_mcoll:    -0.002    +0.002       -0.002          -0.002          +0.002         -0.002     +0.001            -0.004         +0.002        +0.002         -0.002        +0.002         +0.001    +0.000        +0.002        +0.001          -0.003      +0.002    -0.000         +0.001           -0.000         +0.001        -0.004      +0.001    +1.000          +0.001         -0.001   +0.007    -0.001                 +0.003          +0.002        -0.003    -0.012         +0.003      +0.001         +0.001                +0.002             +0.001
//                          :        vbf_dphi_met_ll:    -0.004    +0.003       -0.000          +0.003          -0.004         +0.001     -0.001            +0.001         -0.003        -0.001         -0.001        -0.004         -0.002    +0.001        -0.002        -0.002          +0.021      -0.000    -0.002         -0.002           -0.001         -0.004        -0.000      +0.001    +0.001          +1.000         +0.000   +0.003    -0.003                 +0.005          +0.014        -0.004    -0.004         -0.002      +0.002         +0.010                -0.001             -0.001
//                          :         vbf_bjet_1_phi:    +0.002    -0.004       -0.002          -0.000          -0.000         +0.001     +0.000            -0.000         -0.005        -0.000         -0.001        +0.004         +0.001    -0.004        -0.004        -0.001          +0.007      +0.002    -0.040         -0.101           +0.002         -0.058        -0.003      -0.002    -0.001          +0.000         +1.000   +0.002    -0.011                 +0.001          -0.000        -0.000    -0.002         -0.081      +0.000         -0.001                -0.000             +0.000
//                          :               vbf_ll_m:    +0.002    +0.004       +0.001          -0.004          +0.054         -0.004     +0.194            -0.131         -0.002        +0.161         +0.002        +0.039         +0.001    +0.011        +0.039        +0.024          -0.005      -0.006    +0.002         -0.001           +0.306         -0.006        +0.255      +0.004    +0.007          +0.003         +0.002   +1.000    -0.001                 +0.014          -0.002        +0.221    +0.001         +0.004      +0.005         +0.378                +0.161             +0.194
//                          :              vbf_1_phi:    +0.001    -0.003       +0.003          +0.003          +0.001         +0.002     -0.001            +0.002         -0.006        -0.001         -0.003        +0.005         -0.001    -0.001        -0.001        -0.001          +0.008      -0.003    -0.035         -0.077           +0.001         -0.037        -0.001      +0.003    -0.001          -0.003         -0.011   -0.001    +1.000                 +0.000          -0.000        -0.002    -0.001         -0.070      -0.000         -0.003                -0.001             -0.001
//                          : vbf_met_phi_centrality:    +0.001    +0.008       +0.113          +0.003          -0.048         -0.002     -0.003            +0.075         +0.007        -0.035         +0.006        -0.087         -0.005    +0.078        +0.015        -0.040          -0.004      +0.023    +0.002         -0.006           -0.247         -0.006        +0.059      +0.078    +0.003          +0.005         +0.001   +0.014    +0.000                 +1.000          +0.000        +0.040    +0.050         -0.001      +0.104         +0.428                -0.035             -0.003
//                          :        vbf_bb_deltaphi:    +0.002    +0.004       -0.000          +0.001          -0.000         +0.001     -0.003            -0.001         +0.001        -0.003         +0.001        -0.001         -0.001    -0.002        -0.003        +0.002          -0.004      +0.002    -0.000         -0.000           -0.003         -0.003        +0.001      -0.001    +0.002          +0.014         -0.000   -0.002    -0.000                 +0.000          +1.000        -0.002    -0.002         -0.003      -0.000         +0.004                -0.003             -0.003
//                          :          vbf_lept_0_pt:    -0.002    -0.002       +0.146          +0.001          +0.001         +0.001     +0.266            -0.010         +0.001        +0.237         -0.000        -0.040         -0.000    +0.090        +0.085        -0.002          +0.001      -0.089    +0.001         -0.001           +0.311         -0.000        +0.196      +0.027    -0.003          -0.004         -0.000   +0.221    -0.002                 +0.040          -0.002        +1.000    +0.875         +0.001      -0.043         +0.031                +0.237             +0.266
//                          :              vbf_ll_pt:    +0.000    -0.006       +0.155          +0.001          -0.034         +0.002     +0.219            +0.090         -0.002        +0.177         -0.001        -0.066         +0.000    +0.084        +0.049        -0.025          +0.007      -0.118    +0.000         -0.001           +0.228         +0.002        +0.428      -0.006    -0.012          -0.004         -0.002   +0.001    -0.001                 +0.050          -0.002        +0.875    +1.000         -0.000      -0.061         -0.085                +0.177             +0.219
//                          :         vbf_lept_0_phi:    -0.002    -0.001       +0.001          +0.005          -0.003         +0.007     -0.001            -0.001         +0.001        -0.001         +0.001        +0.001         +0.000    -0.003        -0.002        -0.002          +0.004      -0.000    -0.143         -0.070           +0.004         +0.087        -0.002      -0.001    +0.003          -0.002         -0.081   +0.004    -0.070                 -0.001          -0.003        +0.001    -0.000         +1.000      +0.000         -0.003                -0.001             -0.001
//                          :            vbf_m_t2_bb:    +0.001    -0.001       -0.028          -0.003          -0.041         -0.001     +0.012            +0.013         -0.002        +0.297         -0.003        -0.373         +0.002    +0.386        +0.128        +0.087          +0.002      +0.063    -0.008         +0.003           +0.201         +0.003        -0.047      +0.376    +0.001          +0.002         +0.000   +0.005    -0.000                 +0.104          -0.000        -0.043    -0.061         +0.000      +1.000         -0.110                +0.297             +0.012
//                          :         vbf_mmc_minu3p:    -0.002    +0.005       +0.013          +0.003          +0.009         +0.002     +0.067            -0.010         +0.003        -0.139         +0.002        -0.004         -0.001    +0.011        +0.008        +0.009          -0.012      +0.023    +0.003         -0.002           -0.324         -0.007        +0.096      -0.320    +0.001          +0.010         -0.001   +0.378    -0.003                 +0.428          +0.004        +0.031    -0.085         -0.003      -0.110         +1.000                -0.139             +0.067
//                          :  vbf_pt_bbllmet_vector:    +0.000    -0.001       +0.090          -0.001          +0.735         -0.002     +0.843            -0.048         -0.004        +1.000         -0.004        +0.310         -0.001    +0.346        +0.609        +0.501          +0.003      +0.011    -0.002         +0.001           +0.498         +0.000        +0.034      +0.406    +0.002          -0.001         -0.000   +0.161    -0.001                 -0.035          -0.003        +0.237    +0.177         -0.001      +0.297         -0.139                +1.000             +0.843
//                          :     vbf_pt_bbll_vector:    +0.003    -0.002       +0.056          +0.000          +0.849         -0.001     +1.000            +0.048         -0.002        +0.843         -0.000        +0.425         -0.001    +0.282        +0.602        +0.563          +0.002      +0.017    -0.003         +0.000           +0.138         +0.000        +0.087      -0.005    +0.001          -0.001         +0.000   +0.194    -0.001                 -0.003          -0.003        +0.266    +0.219         -0.001      +0.012         +0.067                +0.843             +1.000
//                          : --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// DataSetFactory           : [dataset] :
//                          :

// %% [markdown]
// ### Booking Deep Neural Network
//
// Here we book the new DNN of TMVA. If using master version you can use the new DL method

// %%
bool useDL = false;

// %% [markdown]
// #### 1. Define DNN layout
//
// The DNN configuration os defined using a string. Note that whitespaces between characters are not allowed.
//
// We define first the DNN layout:
//
// - **input layout** :   this defines the input data format for the DNN as  ``input depth | height | width``.
//    In case of a dense layer as first layer the input layout should be  ``1 | 1 | number of input variables`` (features)
// - **batch layout**  : this defines how are the input batch. It is related to input layout but not the same.
//    If the first layer is dense it should be ``1 | batch size ! number of variables`` (fetures)
//
//    *(note the use of the character `|` as  separator of  input parameters for DNN layout)*
//
// - **layer layout** string defining the layer architecture. The syntax is
//    - layer type (e.g. DENSE, CONV, RNN)
//    - layer parameters (e.g. number of units)
//    - activation function (e.g  TANH, RELU,...)
//
//      *the different layers are separated by the ``","`` *
//
// #### 2. Define Trainining Strategy
//
// We define here the training strategy parameters for the DNN. The parameters are separated by the ``","`` separator.
// One can then concatenate different training strategy with different parameters. The training strategy are separated by
// the ``"|"`` separator.
//
//  - Optimizer
//  - Learning rate
//  - Momentum (valid for SGD and RMSPROP)
//  - Regularization and Weight Decay
//  - Dropout
//  - Max number of epochs
//  - Convergence steps. if the test error will not decrease after that value the training will stop
//  - Batch size (This value must be the same specified in the input layout)
//  - Test Repetitions (the interval when the test error will be computed)
//
//
// #### 3. Define general DNN options
//
// We define the general DNN options concateneting in the final string the previously defined layout and training strategy.
// Note we use the ``":"`` separator to separate the different higher level options, as in the other TMVA methods.
// In addition to input layout, batch layout and training strategy we add now:
//
// - Type of Loss function (e.g. cross entropy)
// - Weight Initizalization (e.g XAVIER, XAVIERUNIFORM, NORMAL )
// - Variable Transformation
// - Type of Architecture (e.g. CPU, GPU, Standard)
//
// We can then book the DL method using the built otion string

// %%
if (useDL) {  
     // Define DNN layout
     TString inputLayoutString = "InputLayout=1|1|35"; 
     TString batchLayoutString= "BatchLayout=1|128|35";
     TString layoutString ("Layout=DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|1|LINEAR");
                                                                                                                                                                                    
      // Define Training strategies 
      // one can catenate several training strategies 
      TString training1("LearningRate=1e-2,Momentum=0.9,Repetitions=1,"
                        "ConvergenceSteps=10,BatchSize=128,TestRepetitions=1,"
                        "MaxEpochs=30,WeightDecay=1e-4,Regularization=None,"
                        "Optimizer=ADAM,DropConfig=0.0+0.0+0.0+0.");
 //     TString training2("LearningRate=1e-3,Momentum=0.9,Repetitions=1,"
 //                       "ConvergenceSteps=10,BatchSize=128,TestRepetitions=1,"
 //                       "MaxEpochs=20,WeightDecay=1e-4,Regularization=None,"
 //                       "Optimizer=SGD,DropConfig=0.0+0.0+0.0+0.");
  
      TString trainingStrategyString ("TrainingStrategy=");
      trainingStrategyString += training1; // + "|" + training2;

      // General Options.                                                                                                                                                                
      TString dnnOptions ("!H:V:ErrorStrategy=CROSSENTROPY:VarTransform=G:"
                          "WeightInitialization=XAVIER");
      dnnOptions.Append (":"); dnnOptions.Append (inputLayoutString);
      dnnOptions.Append (":"); dnnOptions.Append (batchLayoutString);
      dnnOptions.Append (":"); dnnOptions.Append (layoutString);
      dnnOptions.Append (":"); dnnOptions.Append (trainingStrategyString);

      dnnOptions += ":Architecture=CPU";
      factory.BookMethod(loader, TMVA::Types::kDL, "DL_CPU", dnnOptions);

}

// %% [markdown]
// ## Train Methods
//
// Here we train all the previously booked methods.

// %%
factory.TrainAllMethods();
// Out:
// Factory                  : Train all methods
// Factory                  : [dataset] : Create Transformation "I" with events from all classes.
//                          :
//                          : Transformation, Variable selection :
//                          : Input : variable 'vbf_0_eta' <---> Output : variable 'vbf_0_eta'
//                          : Input : variable 'vbf_1_eta' <---> Output : variable 'vbf_1_eta'
//                          : Input : variable 'vbf_jet_1_pt' <---> Output : variable 'vbf_jet_1_pt'
//                          : Input : variable 'vbf_dijets_DEta' <---> Output : variable 'vbf_dijets_DEta'
//                          : Input : variable 'vbf_Dijets_Mass' <---> Output : variable 'vbf_Dijets_Mass'
//                          : Input : variable 'vbf_bjet_0_eta' <---> Output : variable 'vbf_bjet_0_eta'
//                          : Input : variable 'vbf_m_bbll' <---> Output : variable 'vbf_m_bbll'
//                          : Input : variable 'vbf_deltar_min_bl' <---> Output : variable 'vbf_deltar_min_bl'
//                          : Input : variable 'vbf_lept_0_eta' <---> Output : variable 'vbf_lept_0_eta'
//                          : Input : variable 'vbf_m_bbllmet' <---> Output : variable 'vbf_m_bbllmet'
//                          : Input : variable 'vbf_lept_1_eta' <---> Output : variable 'vbf_lept_1_eta'
//                          : Input : variable 'vbf_bb_deltar' <---> Output : variable 'vbf_bb_deltar'
//                          : Input : variable 'vbf_bjet_1_eta' <---> Output : variable 'vbf_bjet_1_eta'
//                          : Input : variable 'vbf_bb_pt' <---> Output : variable 'vbf_bb_pt'
//                          : Input : variable 'vbf_bjet_0_pt' <---> Output : variable 'vbf_bjet_0_pt'
//                          : Input : variable 'vbf_bjet_1_pt' <---> Output : variable 'vbf_bjet_1_pt'
//                          : Input : variable 'vbf_ll_deltaphi' <---> Output : variable 'vbf_ll_deltaphi'
//                          : Input : variable 'vbf_m_ttbar' <---> Output : variable 'vbf_m_ttbar'
//                          : Input : variable 'vbf_0_phi' <---> Output : variable 'vbf_0_phi'
//                          : Input : variable 'vbf_bjet_0_phi' <---> Output : variable 'vbf_bjet_0_phi'
//                          : Input : variable 'vbf_sum_met_ptll' <---> Output : variable 'vbf_sum_met_ptll'
//                          : Input : variable 'vbf_lept_1_phi' <---> Output : variable 'vbf_lept_1_phi'
//                          : Input : variable 'vbf_lept_1_pt' <---> Output : variable 'vbf_lept_1_pt'
//                          : Input : variable 'vbf_met_met' <---> Output : variable 'vbf_met_met'
//                          : Input : variable 'vbf_mcoll' <---> Output : variable 'vbf_mcoll'
//                          : Input : variable 'vbf_dphi_met_ll' <---> Output : variable 'vbf_dphi_met_ll'
//                          : Input : variable 'vbf_bjet_1_phi' <---> Output : variable 'vbf_bjet_1_phi'
//                          : Input : variable 'vbf_ll_m' <---> Output : variable 'vbf_ll_m'
//                          : Input : variable 'vbf_1_phi' <---> Output : variable 'vbf_1_phi'
//                          : Input : variable 'vbf_met_phi_centrality' <---> Output : variable 'vbf_met_phi_centrality'
//                          : Input : variable 'vbf_bb_deltaphi' <---> Output : variable 'vbf_bb_deltaphi'
//                          : Input : variable 'vbf_lept_0_pt' <---> Output : variable 'vbf_lept_0_pt'
//                          : Input : variable 'vbf_ll_pt' <---> Output : variable 'vbf_ll_pt'
//                          : Input : variable 'vbf_lept_0_phi' <---> Output : variable 'vbf_lept_0_phi'
//                          : Input : variable 'vbf_m_t2_bb' <---> Output : variable 'vbf_m_t2_bb'
//                          : Input : variable 'vbf_mmc_minu3p' <---> Output : variable 'vbf_mmc_minu3p'
//                          : Input : variable 'vbf_pt_bbllmet_vector' <---> Output : variable 'vbf_pt_bbllmet_vector'
//                          : Input : variable 'vbf_pt_bbll_vector' <---> Output : variable 'vbf_pt_bbll_vector'
// TFHandler_Factory        :               Variable                      Mean                      RMS              [        Min                      Max ]
//                          : ---------------------------------------------------------------------------------------------------------------------------------
//                          :              vbf_0_eta:               0.0020968                  2.5803   [                 -4.7916                  4.7917 ]
//                          :              vbf_1_eta:               -0.015402                  2.8640   [                 -4.8106                  4.8008 ]
//                          :           vbf_jet_1_pt:                  60008.                  34880.   [                  30000.              1.3283e+06 ]
//                          :        vbf_dijets_DEta:              -0.0095796                  1.1806   [                 -4.9529                  4.9935 ]
//                          :        vbf_Dijets_Mass:              1.3172e+05                  78150.   [                  10225.              3.3733e+06 ]
//                          :         vbf_bjet_0_eta:               -0.012232                  1.1367   [                 -2.5000                  2.4998 ]
//                          :             vbf_m_bbll:              3.1706e+05              1.4590e+05   [                  46801.              3.6490e+06 ]
//                          :      vbf_deltar_min_bl:                  1.5931                 0.75411   [                 0.37165                  4.7799 ]
//                          :         vbf_lept_0_eta:              -0.0019840                  1.1237   [                 -2.6994                  2.6954 ]
//                          :          vbf_m_bbllmet:              4.1911e+05              1.6490e+05   [                  75608.              4.1582e+06 ]
//                          :         vbf_lept_1_eta:              -0.0028579                  1.1733   [                 -2.6996                  2.6990 ]
//                          :          vbf_bb_deltar:                  2.0714                 0.81562   [                 0.38685                  5.8520 ]
//                          :         vbf_bjet_1_eta:              -0.0026520                  1.1965   [                 -2.5000                  2.5000 ]
//                          :              vbf_bb_pt:              1.1118e+05                  75429.   [                  180.56              1.4633e+06 ]
//                          :          vbf_bjet_0_pt:              1.0540e+05                  58119.   [                  20080.              1.5218e+06 ]
//                          :          vbf_bjet_1_pt:                  53183.                  28502.   [                  20000.              9.4298e+05 ]
//                          :        vbf_ll_deltaphi:              -0.0088555                  1.4701   [                 -3.1416                  3.1416 ]
//                          :            vbf_m_ttbar:                  162.20                  292.36   [                 -999.00                  700.00 ]
//                          :              vbf_0_phi:               0.0051693                  1.8107   [                 -3.1416                  3.1416 ]
//                          :         vbf_bjet_0_phi:              -0.0085158                  1.8184   [                 -3.1416                  3.1416 ]
//                          :       vbf_sum_met_ptll:              1.4690e+05                  61279.   [                  16747.              1.2848e+06 ]
//                          :         vbf_lept_1_phi:                0.013060                  1.8130   [                 -3.1416                  3.1416 ]
//                          :          vbf_lept_1_pt:                  28115.                  15564.   [                  9000.0              3.8418e+05 ]
//                          :            vbf_met_met:                  83974.                  58185.   [                  106.74              9.4816e+05 ]
//                          :              vbf_mcoll:                  21603.              2.7847e+07   [             -1.2117e+10              1.6843e+10 ]
//                          :        vbf_dphi_met_ll:               -0.011894                  1.6568   [                 -3.1416                  3.1416 ]
//                          :         vbf_bjet_1_phi:               -0.017278                  1.8135   [                 -3.1416                  3.1416 ]
//                          :               vbf_ll_m:                  50550.                  21645.   [                  15000.              1.1000e+05 ]
//                          :              vbf_1_phi:              -0.0054774                  1.8118   [                 -3.1416                  3.1416 ]
//                          : vbf_met_phi_centrality:                 0.10168                 0.63994   [                 -1.0000                  1.0000 ]
//                          :        vbf_bb_deltaphi:               0.0041788                  1.8873   [                 -3.1416                  3.1416 ]
//                          :          vbf_lept_0_pt:                  62889.                  34205.   [                  13346.              1.0925e+06 ]
//                          :              vbf_ll_pt:                  77476.                  46888.   [                  77.334              1.1216e+06 ]
//                          :         vbf_lept_0_phi:                0.019613                  1.8077   [                 -3.1415                  3.1416 ]
//                          :            vbf_m_t2_bb:                  53.184                  45.063   [                  1.5106                  678.46 ]
//                          :         vbf_mmc_minu3p:                  51.030                  53.247   [                  0.0000                  370.85 ]
//                          :  vbf_pt_bbllmet_vector:              4.1911e+05              1.6490e+05   [                  75608.              4.1582e+06 ]
//                          :     vbf_pt_bbll_vector:              3.1706e+05              1.4590e+05   [                  46801.              3.6490e+06 ]
//                          : ---------------------------------------------------------------------------------------------------------------------------------
//                          :
//                          : <PlotVariables> Will not produce scatter plots ==>
//                          : |  The number of 38 input variables and 0 target values would require 703 two-dimensional
//                          : |  histograms, which would occupy the computer's memory. Note that this
//                          : |  suppression does not have any consequences for your analysis, other
//                          : |  than not disposing of these scatter plots. You can modify the maximum
//                          : |  number of input variables allowed to generate scatter plots in your
//                          : |  script via the command line:
//                          : |  "(TMVA::gConfig().GetVariablePlotting()).fMaxNumOfAllowedVariablesForScatterPlots = <some int>;"
//                          :
//                          : Some more output
//                          : Ranking input variables (method unspecific)...
// IdTransformation         : Ranking result (top variable is best ranked)
//                          : -----------------------------------------------
//                          : Rank : Variable               : Separation
//                          : -----------------------------------------------
//                          :    1 : vbf_Dijets_Mass        : 3.233e-01
//                          :    2 : vbf_deltar_min_bl      : 2.197e-01
//                          :    3 : vbf_m_ttbar            : 1.657e-01
//                          :    4 : vbf_ll_m               : 1.528e-01
//                          :    5 : vbf_mmc_minu3p         : 1.163e-01
//                          :    6 : vbf_1_eta              : 9.286e-02
//                          :    7 : vbf_0_eta              : 9.228e-02
//                          :    8 : vbf_dphi_met_ll        : 8.657e-02
//                          :    9 : vbf_m_bbll             : 8.473e-02
//                          :   10 : vbf_pt_bbll_vector     : 8.473e-02
//                          :   11 : vbf_met_phi_centrality : 7.745e-02
//                          :   12 : vbf_bb_deltar          : 7.182e-02
//                          :   13 : vbf_dijets_DEta        : 5.855e-02
//                          :   14 : vbf_sum_met_ptll       : 5.749e-02
//                          :   15 : vbf_m_bbllmet          : 4.952e-02
//                          :   16 : vbf_pt_bbllmet_vector  : 4.952e-02
//                          :   17 : vbf_ll_deltaphi        : 4.281e-02
//                          :   18 : vbf_m_t2_bb            : 4.043e-02
//                          :   19 : vbf_bb_pt              : 3.950e-02
//                          :   20 : vbf_bb_deltaphi        : 2.791e-02
//                          :   21 : vbf_ll_pt              : 2.467e-02
//                          :   22 : vbf_lept_0_eta         : 2.304e-02
//                          :   23 : vbf_met_met            : 2.036e-02
//                          :   24 : vbf_lept_1_pt          : 1.625e-02
//                          :   25 : vbf_bjet_0_eta         : 1.493e-02
//                          :   26 : vbf_lept_1_eta         : 1.436e-02
//                          :   27 : vbf_lept_0_pt          : 1.190e-02
//                          :   28 : vbf_jet_1_pt           : 1.080e-02
//                          :   29 : vbf_bjet_1_pt          : 9.940e-03
//                          :   30 : vbf_bjet_1_eta         : 7.494e-03
//                          :   31 : vbf_bjet_0_pt          : 6.730e-03
//                          :   32 : vbf_lept_1_phi         : 1.890e-03
//                          :   33 : vbf_bjet_1_phi         : 1.851e-03
//                          :   34 : vbf_0_phi              : 1.464e-03
//                          :   35 : vbf_lept_0_phi         : 1.419e-03
//                          :   36 : vbf_bjet_0_phi         : 1.141e-03
//                          :   37 : vbf_1_phi              : 1.102e-03
//                          :   38 : vbf_mcoll              : 1.085e-03
//                          : -----------------------------------------------
// Factory                  : Train method: BDT for Classification
//                          :
// <WARNING>                : Events with negative event weights are USED during the BDT training. This might cause problems with small node sizes or with the boosting. Please remove negative events from training using the option *IgnoreEventsWithNegWeightsInTraining* in case you observe problems with the boosting
// BDT                      : #events: (reweighted) sig: 246648 bkg: 246648
//                          : #events: (unweighted) sig: 8990 bkg: 484305
//                          : Training 350 Decision Trees ... patience please
//                          : Elapsed time for training with 493295 events: 269 sec
// BDT                      : [dataset] : Evaluation of BDT on training sample (493295 events)
//                          : Elapsed time for evaluation of 493295 events: 11.5 sec
//                          : Creating xml weight file: dataset/weights/TMVA_Higgs_Classification_BDT.weights.xml
//                          : Creating standalone class: dataset/weights/TMVA_Higgs_Classification_BDT.class.C
//                          : Higgs_ClassificationOutputVBFbkgNN.root:/dataset/Method_BDT/BDT
// Factory                  : Training finished
//                          :
//                          : Ranking input variables (method specific)...
// BDT                      : Ranking result (top variable is best ranked)
//                          : --------------------------------------------------------
//                          : Rank : Variable               : Variable Importance
//                          : --------------------------------------------------------
//                          :    1 : vbf_Dijets_Mass        : 6.292e-02
//                          :    2 : vbf_ll_m               : 5.265e-02
//                          :    3 : vbf_m_bbll             : 4.797e-02
//                          :    4 : vbf_0_eta              : 4.440e-02
//                          :    5 : vbf_1_eta              : 4.374e-02
//                          :    6 : vbf_mmc_minu3p         : 3.812e-02
//                          :    7 : vbf_deltar_min_bl      : 3.592e-02
//                          :    8 : vbf_lept_0_eta         : 3.511e-02
//                          :    9 : vbf_met_phi_centrality : 3.266e-02
//                          :   10 : vbf_bb_deltar          : 3.121e-02
//                          :   11 : vbf_dphi_met_ll        : 3.108e-02
//                          :   12 : vbf_sum_met_ptll       : 3.107e-02
//                          :   13 : vbf_m_ttbar            : 3.056e-02
//                          :   14 : vbf_m_t2_bb            : 2.864e-02
//                          :   15 : vbf_lept_1_eta         : 2.765e-02
//                          :   16 : vbf_bjet_1_eta         : 2.739e-02
//                          :   17 : vbf_dijets_DEta        : 2.567e-02
//                          :   18 : vbf_0_phi              : 2.527e-02
//                          :   19 : vbf_jet_1_pt           : 2.519e-02
//                          :   20 : vbf_lept_0_phi         : 2.473e-02
//                          :   21 : vbf_bb_deltaphi        : 2.400e-02
//                          :   22 : vbf_bjet_0_eta         : 2.356e-02
//                          :   23 : vbf_met_met            : 2.347e-02
//                          :   24 : vbf_ll_deltaphi        : 2.264e-02
//                          :   25 : vbf_1_phi              : 2.262e-02
//                          :   26 : vbf_bjet_0_phi         : 2.243e-02
//                          :   27 : vbf_lept_1_phi         : 2.238e-02
//                          :   28 : vbf_bjet_1_phi         : 2.083e-02
//                          :   29 : vbf_lept_1_pt          : 2.055e-02
//                          :   30 : vbf_bb_pt              : 2.019e-02
//                          :   31 : vbf_bjet_1_pt          : 1.997e-02
//                          :   32 : vbf_m_bbllmet          : 1.528e-02
//                          :   33 : vbf_bjet_0_pt          : 1.370e-02
//                          :   34 : vbf_ll_pt              : 1.334e-02
//                          :   35 : vbf_lept_0_pt          : 1.311e-02
//                          :   36 : vbf_mcoll              : 0.000e+00
//                          :   37 : vbf_pt_bbllmet_vector  : 0.000e+00
//                          :   38 : vbf_pt_bbll_vector     : 0.000e+00
//                          : --------------------------------------------------------
// Factory                  : === Destroy and recreate all methods via weight files for testing ===
//                          :
//                          : Reading weight file: dataset/weights/TMVA_Higgs_Classification_BDT.weights.xml

// %% [markdown]
// ## Test  all methods
//
// Here we test all methods using the test data set

// %%
factory.TestAllMethods();
// Out:
// Factory                  : Test all methods
// Factory                  : Test method: BDT for Classification performance
//                          :
// BDT                      : [dataset] : Evaluation of BDT on testing sample (1478804 events)
//                          : Elapsed time for evaluation of 1478804 events: 28.5 sec

// %% [raw]
// ## Evaluate all methods
//
// Here we evaluate all methods and compare their performances, computing efficiencies, ROC curves etc.. using both training and tetsing data sets. Several histograms are produced which can be examined with the TMVAGui or directly using the output file

// %%
factory.EvaluateAllMethods();
// Out:
// Factory                  : Evaluate all methods
// Factory                  : Evaluate classifier: BDT
//                          :
// BDT                      : [dataset] : Loop over test events and fill histograms with classifier response...
//                          :
// TFHandler_BDT            :               Variable                      Mean                      RMS              [        Min                      Max ]
//                          : ---------------------------------------------------------------------------------------------------------------------------------
//                          :              vbf_0_eta:              -0.0010488                  2.5780   [                 -4.8007                  4.8050 ]
//                          :              vbf_1_eta:               -0.019892                  2.8570   [                 -4.8112                  4.8126 ]
//                          :           vbf_jet_1_pt:                  60103.                  35299.   [                  30000.              1.4452e+06 ]
//                          :        vbf_dijets_DEta:              -0.0065327                  1.1742   [                 -4.9292                  4.9141 ]
//                          :        vbf_Dijets_Mass:              1.3117e+05                  77899.   [                  9375.3              3.0582e+06 ]
//                          :         vbf_bjet_0_eta:             -0.00079206                  1.1341   [                 -2.5000                  2.5000 ]
//                          :             vbf_m_bbll:              3.1738e+05              1.4895e+05   [                  45557.              3.7916e+06 ]
//                          :      vbf_deltar_min_bl:                  1.5927                 0.75514   [                 0.38680                  4.9705 ]
//                          :         vbf_lept_0_eta:               0.0061960                  1.1272   [                 -2.6977                  2.6987 ]
//                          :          vbf_m_bbllmet:              4.1972e+05              1.6901e+05   [                  66812.              4.5185e+06 ]
//                          :         vbf_lept_1_eta:               0.0060640                  1.1705   [                 -2.6997                  2.6998 ]
//                          :          vbf_bb_deltar:                  2.0662                 0.82056   [                 0.35845                  5.7365 ]
//                          :         vbf_bjet_1_eta:               0.0057407                  1.1855   [                 -2.5000                  2.5000 ]
//                          :              vbf_bb_pt:              1.1162e+05                  76877.   [                  20.635              1.6290e+06 ]
//                          :          vbf_bjet_0_pt:              1.0567e+05                  59099.   [                  20043.              1.9756e+06 ]
//                          :          vbf_bjet_1_pt:                  53223.                  28821.   [                  20000.              9.3370e+05 ]
//                          :        vbf_ll_deltaphi:               0.0045655                  1.4688   [                 -3.1416                  3.1416 ]
//                          :            vbf_m_ttbar:                  162.79                  291.95   [                 -999.00                  700.00 ]
//                          :              vbf_0_phi:              -0.0025382                  1.8129   [                 -3.1416                  3.1416 ]
//                          :         vbf_bjet_0_phi:              -0.0038536                  1.8130   [                 -3.1416                  3.1416 ]
//                          :       vbf_sum_met_ptll:              1.4756e+05                  61589.   [                  16568.              2.3645e+06 ]
//                          :         vbf_lept_1_phi:               0.0099749                  1.8118   [                 -3.1416                  3.1416 ]
//                          :          vbf_lept_1_pt:                  28222.                  15972.   [                  9000.1              5.3349e+05 ]
//                          :            vbf_met_met:                  84303.                  58000.   [                  51.691              1.2962e+06 ]
//                          :              vbf_mcoll:                 -18749.              4.5684e+07   [             -4.6493e+10              3.9141e+10 ]
//                          :        vbf_dphi_met_ll:               0.0064101                  1.6645   [                 -3.1416                  3.1416 ]
//                          :         vbf_bjet_1_phi:              -0.0052111                  1.8110   [                 -3.1416                  3.1416 ]
//                          :               vbf_ll_m:                  50626.                  21643.   [                  15000.              1.1000e+05 ]
//                          :              vbf_1_phi:              -0.0079975                  1.8150   [                 -3.1416                  3.1416 ]
//                          : vbf_met_phi_centrality:                 0.10212                 0.64145   [                 -1.0000                  1.0000 ]
//                          :        vbf_bb_deltaphi:                0.012947                  1.8877   [                 -3.1416                  3.1416 ]
//                          :          vbf_lept_0_pt:                  63308.                  35789.   [                  13274.              1.5508e+06 ]
//                          :              vbf_ll_pt:                  78018.                  48709.   [                  90.325              1.5894e+06 ]
//                          :         vbf_lept_0_phi:               0.0064998                  1.8167   [                 -3.1416                  3.1416 ]
//                          :            vbf_m_t2_bb:                  53.366                  46.219   [                  1.7134                  646.92 ]
//                          :         vbf_mmc_minu3p:                  50.835                  53.299   [                  0.0000                  527.79 ]
//                          :  vbf_pt_bbllmet_vector:              4.1972e+05              1.6901e+05   [                  66812.              4.5185e+06 ]
//                          :     vbf_pt_bbll_vector:              3.1738e+05              1.4895e+05   [                  45557.              3.7916e+06 ]
//                          : ---------------------------------------------------------------------------------------------------------------------------------
//                          :
//                          : <PlotVariables> Will not produce scatter plots ==>
//                          : |  The number of 38 input variables and 0 target values would require 703 two-dimensional
//                          : |  histograms, which would occupy the computer's memory. Note that this
//                          : |  suppression does not have any consequences for your analysis, other
//                          : |  than not disposing of these scatter plots. You can modify the maximum
//                          : |  number of input variables allowed to generate scatter plots in your
//                          : |  script via the command line:
//                          : |  "(TMVA::gConfig().GetVariablePlotting()).fMaxNumOfAllowedVariablesForScatterPlots = <some int>;"
//                          :
//                          : Some more output
//                          :
//                          : Evaluation results ranked by best signal efficiency and purity (area)
//                          : -------------------------------------------------------------------------------------------------------------------
//                          : DataSet       MVA
//                          : Name:         Method:          ROC-integ
//                          : dataset       BDT            : 0.965
//                          : -------------------------------------------------------------------------------------------------------------------
//                          :
//                          : Testing efficiency compared to training efficiency (overtraining check)
//                          : -------------------------------------------------------------------------------------------------------------------
//                          : DataSet              MVA              Signal efficiency: from test sample (from training sample)
//                          : Name:                Method:          @B=0.01             @B=0.10            @B=0.30
//                          : -------------------------------------------------------------------------------------------------------------------
//                          : dataset              BDT            : 0.609 (0.614)       0.897 (0.895)      0.978 (0.977)
//                          : -------------------------------------------------------------------------------------------------------------------
//                          :
// Dataset:dataset          : Created tree 'TestTree' with 1478804 events
//                          :
// Dataset:dataset          : Created tree 'TrainTree' with 493295 events
//                          :
// Factory                  : Thank you for using TMVA!
//                          : For citation information, please visit: http://tmva.sf.net/citeTMVA.html

// %% [markdown]
// ## Plot ROC Curve
// We enable JavaScript visualisation for the plots

// %%
c1 = factory.GetROCCurve(loader);
c1->Draw();

// %% [markdown]
// ####  Close outputfile to save all output information (evaluation result of methods)

// %%
outputFile->Close();
